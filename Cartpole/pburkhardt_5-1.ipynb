# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  

from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"
  
GAMMA = 0.95
LEARNING_RATE = 0.001
  
MEMORY_SIZE = 1000000
BATCH_SIZE = 20
  
EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.01
EXPLORATION_DECAY = 0.995
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 9
# Scores: (min: 9, avg: 9, max: 9)
#
# Run: 2, exploration: 0.960693043575437, score: 19
# Scores: (min: 9, avg: 14, max: 19)
#
# Run: 3, exploration: 0.8183201210226743, score: 33
# Scores: (min: 9, avg: 20.333333333333332, max: 33)
#
# Run: 4, exploration: 0.7076077347272662, score: 30
# Scores: (min: 9, avg: 22.75, max: 33)
#
# Run: 5, exploration: 0.6797938283326578, score: 9
# Scores: (min: 9, avg: 20, max: 33)
#
# Run: 6, exploration: 0.6118738784280476, score: 22
# Scores: (min: 9, avg: 20.333333333333332, max: 33)
#
# Run: 7, exploration: 0.5819594443402982, score: 11
# Scores: (min: 9, avg: 19, max: 33)
#
# Run: 8, exploration: 0.5507399854171277, score: 12
# Scores: (min: 9, avg: 18.125, max: 33)
#
# Run: 9, exploration: 0.5211953074858876, score: 12
# Scores: (min: 9, avg: 17.444444444444443, max: 33)
#
# Run: 10, exploration: 0.483444593917636, score: 16
# Scores: (min: 9, avg: 17.3, max: 33)
#
# Run: 11, exploration: 0.457510005540005, score: 12
# Scores: (min: 9, avg: 16.818181818181817, max: 33)
#
# Run: 12, exploration: 0.43296668905325736, score: 12
# Scores: (min: 9, avg: 16.416666666666668, max: 33)
#
# Run: 13, exploration: 0.4117990041127769, score: 11
# Scores: (min: 9, avg: 16, max: 33)
#
# Run: 14, exploration: 0.3897078735047413, score: 12
# Scores: (min: 9, avg: 15.714285714285714, max: 33)
#
# Run: 15, exploration: 0.3743896431025813, score: 9
# Scores: (min: 9, avg: 15.266666666666667, max: 33)
#
# Run: 16, exploration: 0.29580711868545667, score: 48
# Scores: (min: 9, avg: 17.3125, max: 48)
#
# Run: 17, exploration: 0.19808659230739353, score: 81
# Scores: (min: 9, avg: 21.058823529411764, max: 81)
#
# Run: 18, exploration: 0.12490462201997637, score: 93
# Scores: (min: 9, avg: 25.055555555555557, max: 93)
#
# Run: 19, exploration: 0.08662902049662846, score: 74
# Scores: (min: 9, avg: 27.63157894736842, max: 93)
#
# Run: 20, exploration: 0.06878996970981359, score: 47
# Scores: (min: 9, avg: 28.6, max: 93)
#
# Run: 21, exploration: 0.050162503748802344, score: 64
# Scores: (min: 9, avg: 30.285714285714285, max: 93)
#
# Run: 22, exploration: 0.04063952250178857, score: 43
# Scores: (min: 9, avg: 30.863636363636363, max: 93)
#
# Run: 23, exploration: 0.030235026982422884, score: 60
# Scores: (min: 9, avg: 32.130434782608695, max: 93)
#
# Run: 24, exploration: 0.024991218342344988, score: 39
# Scores: (min: 9, avg: 32.416666666666664, max: 93)
#
# Run: 25, exploration: 0.021394538952450012, score: 32
# Scores: (min: 9, avg: 32.4, max: 93)
#
# Run: 26, exploration: 0.017772843617388175, score: 38
# Scores: (min: 9, avg: 32.61538461538461, max: 93)
#
# Run: 27, exploration: 0.014112977003416188, score: 47
# Scores: (min: 9, avg: 33.148148148148145, max: 93)
#
# Run: 28, exploration: 0.012576201611761997, score: 24
# Scores: (min: 9, avg: 32.82142857142857, max: 93)
#
# Run: 29, exploration: 0.010137759008060509, score: 44
# Scores: (min: 9, avg: 33.206896551724135, max: 93)
#
# Run: 30, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 33.36666666666667, max: 93)
#
# Run: 31, exploration: 0.01, score: 98
# Scores: (min: 9, avg: 35.45161290322581, max: 98)
#
# Run: 32, exploration: 0.01, score: 45
# Scores: (min: 9, avg: 35.75, max: 98)
#
# Run: 33, exploration: 0.01, score: 74
# Scores: (min: 9, avg: 36.90909090909091, max: 98)
#
# Run: 34, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 39.26470588235294, max: 117)
#
# Run: 35, exploration: 0.01, score: 162
# Scores: (min: 9, avg: 42.77142857142857, max: 162)
#
# Run: 36, exploration: 0.01, score: 187
# Scores: (min: 9, avg: 46.77777777777778, max: 187)
#
# Run: 37, exploration: 0.01, score: 277
# Scores: (min: 9, avg: 53, max: 277)
#
# Run: 38, exploration: 0.01, score: 394
# Scores: (min: 9, avg: 61.973684210526315, max: 394)
#
# Run: 39, exploration: 0.01, score: 381
# Scores: (min: 9, avg: 70.15384615384616, max: 394)
#
# Run: 40, exploration: 0.01, score: 235
# Scores: (min: 9, avg: 74.275, max: 394)
#
# Run: 41, exploration: 0.01, score: 214
# Scores: (min: 9, avg: 77.6829268292683, max: 394)
#
# Run: 42, exploration: 0.01, score: 313
# Scores: (min: 9, avg: 83.28571428571429, max: 394)
#
# Run: 43, exploration: 0.01, score: 233
# Scores: (min: 9, avg: 86.76744186046511, max: 394)
#
# Run: 44, exploration: 0.01, score: 297
# Scores: (min: 9, avg: 91.54545454545455, max: 394)
#
# Run: 45, exploration: 0.01, score: 213
# Scores: (min: 9, avg: 94.24444444444444, max: 394)
#
# Run: 46, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 95.65217391304348, max: 394)
#
# Run: 47, exploration: 0.01, score: 199
# Scores: (min: 9, avg: 97.85106382978724, max: 394)
#
# Run: 48, exploration: 0.01, score: 202
# Scores: (min: 9, avg: 100.02083333333333, max: 394)
#
# Run: 49, exploration: 0.01, score: 216
# Scores: (min: 9, avg: 102.38775510204081, max: 394)
#
# Run: 50, exploration: 0.01, score: 176
# Scores: (min: 9, avg: 103.86, max: 394)
#
# Run: 51, exploration: 0.01, score: 184
# Scores: (min: 9, avg: 105.43137254901961, max: 394)
#
# Run: 52, exploration: 0.01, score: 188
# Scores: (min: 9, avg: 107.01923076923077, max: 394)
#
# Run: 53, exploration: 0.01, score: 186
# Scores: (min: 9, avg: 108.50943396226415, max: 394)
#
# Run: 54, exploration: 0.01, score: 221
# Scores: (min: 9, avg: 110.5925925925926, max: 394)
#
# Run: 55, exploration: 0.01, score: 325
# Scores: (min: 9, avg: 114.49090909090908, max: 394)
#
# Run: 56, exploration: 0.01, score: 235
# Scores: (min: 9, avg: 116.64285714285714, max: 394)
#
# Run: 57, exploration: 0.01, score: 429
# Scores: (min: 9, avg: 122.12280701754386, max: 429)
#
# Run: 58, exploration: 0.01, score: 274
# Scores: (min: 9, avg: 124.74137931034483, max: 429)
#
# Run: 59, exploration: 0.01, score: 192
# Scores: (min: 9, avg: 125.88135593220339, max: 429)
#
# Run: 60, exploration: 0.01, score: 195
# Scores: (min: 9, avg: 127.03333333333333, max: 429)
#
# Run: 61, exploration: 0.01, score: 260
# Scores: (min: 9, avg: 129.21311475409837, max: 429)
#
# Run: 62, exploration: 0.01, score: 244
# Scores: (min: 9, avg: 131.06451612903226, max: 429)
#
# Run: 63, exploration: 0.01, score: 217
# Scores: (min: 9, avg: 132.42857142857142, max: 429)
#
# Run: 64, exploration: 0.01, score: 200
# Scores: (min: 9, avg: 133.484375, max: 429)
#
# Run: 65, exploration: 0.01, score: 365
# Scores: (min: 9, avg: 137.04615384615386, max: 429)
#
# Run: 66, exploration: 0.01, score: 210
# Scores: (min: 9, avg: 138.15151515151516, max: 429)
#
# Run: 67, exploration: 0.01, score: 231
# Scores: (min: 9, avg: 139.53731343283582, max: 429)
#
# Run: 68, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 140.13235294117646, max: 429)
#
# Run: 69, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 140.55072463768116, max: 429)
#
# Run: 70, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 141.04285714285714, max: 429)
#
# Run: 71, exploration: 0.01, score: 331
# Scores: (min: 9, avg: 143.71830985915494, max: 429)
#
# Run: 72, exploration: 0.01, score: 160
# Scores: (min: 9, avg: 143.94444444444446, max: 429)
#
# Run: 73, exploration: 0.01, score: 247
# Scores: (min: 9, avg: 145.35616438356163, max: 429)
#
# Run: 74, exploration: 0.01, score: 209
# Scores: (min: 9, avg: 146.21621621621622, max: 429)
#
# Run: 75, exploration: 0.01, score: 197
# Scores: (min: 9, avg: 146.89333333333335, max: 429)
#
# Run: 76, exploration: 0.01, score: 249
# Scores: (min: 9, avg: 148.23684210526315, max: 429)
#
# Run: 77, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 148.64935064935065, max: 429)
#
# Run: 78, exploration: 0.01, score: 277
# Scores: (min: 9, avg: 150.2948717948718, max: 429)
#
# Run: 79, exploration: 0.01, score: 220
# Scores: (min: 9, avg: 151.1772151898734, max: 429)
#
# Run: 80, exploration: 0.01, score: 155
# Scores: (min: 9, avg: 151.225, max: 429)
#
# Run: 81, exploration: 0.01, score: 218
# Scores: (min: 9, avg: 152.0493827160494, max: 429)
#
# Run: 82, exploration: 0.01, score: 240
# Scores: (min: 9, avg: 153.1219512195122, max: 429)
#
# Run: 83, exploration: 0.01, score: 195
# Scores: (min: 9, avg: 153.6265060240964, max: 429)
#
# Run: 84, exploration: 0.01, score: 170
# Scores: (min: 9, avg: 153.82142857142858, max: 429)
#
# Run: 85, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 154.12941176470588, max: 429)
#
# Run: 86, exploration: 0.01, score: 164
# Scores: (min: 9, avg: 154.24418604651163, max: 429)
#
# Run: 87, exploration: 0.01, score: 171
# Scores: (min: 9, avg: 154.4367816091954, max: 429)
#
# Run: 88, exploration: 0.01, score: 230
# Scores: (min: 9, avg: 155.29545454545453, max: 429)
#
# Run: 89, exploration: 0.01, score: 309
# Scores: (min: 9, avg: 157.02247191011236, max: 429)
#
# Run: 90, exploration: 0.01, score: 239
# Scores: (min: 9, avg: 157.93333333333334, max: 429)
#
# Run: 91, exploration: 0.01, score: 250
# Scores: (min: 9, avg: 158.94505494505495, max: 429)
#
# Run: 92, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 158.9891304347826, max: 429)
#
# Run: 93, exploration: 0.01, score: 228
# Scores: (min: 9, avg: 159.7311827956989, max: 429)
#
# Run: 94, exploration: 0.01, score: 236
# Scores: (min: 9, avg: 160.54255319148936, max: 429)
#
# Run: 95, exploration: 0.01, score: 257
# Scores: (min: 9, avg: 161.55789473684212, max: 429)
#
# Run: 96, exploration: 0.01, score: 219
# Scores: (min: 9, avg: 162.15625, max: 429)
#
# Run: 97, exploration: 0.01, score: 122
# Scores: (min: 9, avg: 161.7422680412371, max: 429)
#
# Run: 98, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 160.21428571428572, max: 429)
#
# Run: 99, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 158.7171717171717, max: 429)
#
# Run: 100, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 158.85, max: 429)
#
# Run: 101, exploration: 0.01, score: 191
# Scores: (min: 9, avg: 160.67, max: 429)
#
# Run: 102, exploration: 0.01, score: 264
# Scores: (min: 9, avg: 163.12, max: 429)
#
# Run: 103, exploration: 0.01, score: 221
# Scores: (min: 9, avg: 165, max: 429)
#
# Run: 104, exploration: 0.01, score: 206
# Scores: (min: 9, avg: 166.76, max: 429)
#
# Run: 105, exploration: 0.01, score: 225
# Scores: (min: 9, avg: 168.92, max: 429)
#
# Run: 106, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 170.39, max: 429)
#
# Run: 107, exploration: 0.01, score: 177
# Scores: (min: 9, avg: 172.05, max: 429)
#
# Run: 108, exploration: 0.01, score: 254
# Scores: (min: 9, avg: 174.47, max: 429)
#
# Run: 109, exploration: 0.01, score: 270
# Scores: (min: 9, avg: 177.05, max: 429)
#
# Run: 110, exploration: 0.01, score: 325
# Scores: (min: 9, avg: 180.14, max: 429)
#
# Run: 111, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 181.49, max: 429)
#
# Run: 112, exploration: 0.01, score: 420
# Scores: (min: 9, avg: 185.57, max: 429)
#
# Run: 113, exploration: 0.01, score: 229
# Scores: (min: 9, avg: 187.75, max: 429)
#
# Run: 114, exploration: 0.01, score: 225
# Scores: (min: 9, avg: 189.88, max: 429)
#
# Run: 115, exploration: 0.01, score: 418
# Scores: (min: 12, avg: 193.97, max: 429)
#
# Run: 116, exploration: 0.01, score: 155
# Scores: (min: 12, avg: 195.04, max: 429)
#
# Solved in 16 runs, 116 total runs.

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  

from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"
  
GAMMA = 0.95
LEARNING_RATE = 0.01    # changed learning rate from 0.001 to 0.01
  
MEMORY_SIZE = 1000000
BATCH_SIZE = 20
  
EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.01
EXPLORATION_DECAY = 0.995
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
# changed learning rate from 0.001 to 0.01
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 13
# Scores: (min: 13, avg: 13, max: 13)
#
# Run: 2, exploration: 0.918316468354365, score: 24
# Scores: (min: 13, avg: 18.5, max: 24)
#
# Run: 3, exploration: 0.8778091417340573, score: 10
# Scores: (min: 10, avg: 15.666666666666666, max: 24)
#
# Run: 4, exploration: 0.8061065909263957, score: 18
# Scores: (min: 10, avg: 16.25, max: 24)
#
# Run: 5, exploration: 0.6433260027715241, score: 46
# Scores: (min: 10, avg: 22.2, max: 46)
#
# Run: 6, exploration: 0.5790496471185967, score: 22
# Scores: (min: 10, avg: 22.166666666666668, max: 46)
#
# Run: 7, exploration: 0.5535075230322891, score: 10
# Scores: (min: 10, avg: 20.428571428571427, max: 46)
#
# Run: 8, exploration: 0.5211953074858876, score: 13
# Scores: (min: 10, avg: 19.5, max: 46)
#
# Run: 9, exploration: 0.4932355662165453, score: 12
# Scores: (min: 10, avg: 18.666666666666668, max: 46)
#
# Run: 10, exploration: 0.46211964903917074, score: 14
# Scores: (min: 10, avg: 18.2, max: 46)
#
# Run: 11, exploration: 0.446186062443672, score: 8
# Scores: (min: 8, avg: 17.272727272727273, max: 46)
#
# Run: 12, exploration: 0.42013897252428334, score: 13
# Scores: (min: 8, avg: 16.916666666666668, max: 46)
#
# Run: 13, exploration: 0.3976004408064698, score: 12
# Scores: (min: 8, avg: 16.53846153846154, max: 46)
#
# Run: 14, exploration: 0.37816180712868996, score: 11
# Scores: (min: 8, avg: 16.142857142857142, max: 46)
#
# Run: 15, exploration: 0.3614809303671764, score: 10
# Scores: (min: 8, avg: 15.733333333333333, max: 46)
#
# Run: 16, exploration: 0.3352984938281715, score: 16
# Scores: (min: 8, avg: 15.75, max: 46)
#
# Run: 17, exploration: 0.3157247089126454, score: 13
# Scores: (min: 8, avg: 15.588235294117647, max: 46)
#
# Run: 18, exploration: 0.2987875242397482, score: 12
# Scores: (min: 8, avg: 15.38888888888889, max: 46)
#
# Run: 19, exploration: 0.28417984116121187, score: 11
# Scores: (min: 8, avg: 15.157894736842104, max: 46)
#
# Run: 20, exploration: 0.26759021970270175, score: 13
# Scores: (min: 8, avg: 15.05, max: 46)
#
# Run: 21, exploration: 0.25450776877280124, score: 11
# Scores: (min: 8, avg: 14.857142857142858, max: 46)
#
# Run: 22, exploration: 0.24450384299593592, score: 9
# Scores: (min: 8, avg: 14.590909090909092, max: 46)
#
# Run: 23, exploration: 0.23371867538818816, score: 10
# Scores: (min: 8, avg: 14.391304347826088, max: 46)
#
# Run: 24, exploration: 0.2167901907234072, score: 16
# Scores: (min: 8, avg: 14.458333333333334, max: 46)
#
# Run: 25, exploration: 0.20619134658263935, score: 11
# Scores: (min: 8, avg: 14.32, max: 46)
#
# Run: 26, exploration: 0.19611067854912728, score: 11
# Scores: (min: 8, avg: 14.192307692307692, max: 46)
#
# Run: 27, exploration: 0.18840216465300522, score: 9
# Scores: (min: 8, avg: 14, max: 46)
#
# Run: 28, exploration: 0.1800916657318127, score: 10
# Scores: (min: 8, avg: 13.857142857142858, max: 46)
#
# Run: 29, exploration: 0.17214774642209296, score: 10
# Scores: (min: 8, avg: 13.724137931034482, max: 46)
#
# Run: 30, exploration: 0.1662122034722543, score: 8
# Scores: (min: 8, avg: 13.533333333333333, max: 46)
#
# Run: 31, exploration: 0.1549480222912372, score: 15
# Scores: (min: 8, avg: 13.580645161290322, max: 46)
#
# Run: 32, exploration: 0.14157986400593744, score: 19
# Scores: (min: 8, avg: 13.75, max: 46)
#
# Run: 33, exploration: 0.13198501352907185, score: 15
# Scores: (min: 8, avg: 13.787878787878787, max: 46)
#
# Run: 34, exploration: 0.1261630989318213, score: 10
# Scores: (min: 8, avg: 13.676470588235293, max: 46)
#
# Run: 35, exploration: 0.11999500148501063, score: 11
# Scores: (min: 8, avg: 13.6, max: 46)
#
# Run: 36, exploration: 0.11412846151764894, score: 11
# Scores: (min: 8, avg: 13.527777777777779, max: 46)
#
# Run: 37, exploration: 0.09868776295209031, score: 30
# Scores: (min: 8, avg: 13.972972972972974, max: 46)
#
# Run: 38, exploration: 0.09480864735409487, score: 9
# Scores: (min: 8, avg: 13.842105263157896, max: 46)
#
# Run: 39, exploration: 0.09108200798387568, score: 9
# Scores: (min: 8, avg: 13.717948717948717, max: 46)
#
# Run: 40, exploration: 0.08706434220766679, score: 10
# Scores: (min: 8, avg: 13.625, max: 46)
#
# Run: 41, exploration: 0.08198177029173696, score: 13
# Scores: (min: 8, avg: 13.609756097560975, max: 46)
#
# Run: 42, exploration: 0.07875931641927113, score: 9
# Scores: (min: 8, avg: 13.5, max: 46)
#
# Run: 43, exploration: 0.07604374613140748, score: 8
# Scores: (min: 8, avg: 13.372093023255815, max: 46)
#
# Run: 44, exploration: 0.07342180695061275, score: 8
# Scores: (min: 8, avg: 13.25, max: 46)
#
# Run: 45, exploration: 0.07053581918419231, score: 9
# Scores: (min: 8, avg: 13.155555555555555, max: 46)
#
# Run: 46, exploration: 0.0677632708131484, score: 9
# Scores: (min: 8, avg: 13.065217391304348, max: 46)
#
# Run: 47, exploration: 0.06477420436570952, score: 10
# Scores: (min: 8, avg: 13, max: 46)
#
# Run: 48, exploration: 0.06191698689958447, score: 10
# Scores: (min: 8, avg: 12.9375, max: 46)
#
# Run: 49, exploration: 0.05948321859358224, score: 9
# Scores: (min: 8, avg: 12.857142857142858, max: 46)
#
# Run: 50, exploration: 0.05685938874076987, score: 10
# Scores: (min: 8, avg: 12.8, max: 46)
#
# Run: 51, exploration: 0.0543512971290831, score: 10
# Scores: (min: 8, avg: 12.745098039215685, max: 46)
#
# Run: 52, exploration: 0.052214913061211746, score: 9
# Scores: (min: 8, avg: 12.673076923076923, max: 46)
#
# Run: 53, exploration: 0.050162503748802344, score: 9
# Scores: (min: 8, avg: 12.60377358490566, max: 46)
#
# Run: 54, exploration: 0.04794981455780219, score: 10
# Scores: (min: 8, avg: 12.555555555555555, max: 46)
#
# Run: 55, exploration: 0.046065053286412784, score: 9
# Scores: (min: 8, avg: 12.49090909090909, max: 46)
#
# Run: 56, exploration: 0.04403310436296763, score: 10
# Scores: (min: 8, avg: 12.446428571428571, max: 46)
#
# Run: 57, exploration: 0.04230229704853423, score: 9
# Scores: (min: 8, avg: 12.385964912280702, max: 46)
#
# Run: 58, exploration: 0.04063952250178857, score: 9
# Scores: (min: 8, avg: 12.327586206896552, max: 46)
#
# Run: 59, exploration: 0.0386526615487428, score: 11
# Scores: (min: 8, avg: 12.305084745762711, max: 46)
#
# Run: 60, exploration: 0.03694767635022522, score: 10
# Scores: (min: 8, avg: 12.266666666666667, max: 46)
#
# Run: 61, exploration: 0.035317898767708356, score: 10
# Scores: (min: 8, avg: 12.229508196721312, max: 46)
#
# Run: 62, exploration: 0.033760011361539714, score: 10
# Scores: (min: 8, avg: 12.193548387096774, max: 46)
#
# Run: 63, exploration: 0.032433008066058915, score: 9
# Scores: (min: 8, avg: 12.142857142857142, max: 46)
#
# Run: 64, exploration: 0.03100237440513238, score: 10
# Scores: (min: 8, avg: 12.109375, max: 46)
#
# Run: 65, exploration: 0.029634846598205186, score: 10
# Scores: (min: 8, avg: 12.076923076923077, max: 46)
#
# Run: 66, exploration: 0.028186002814352063, score: 11
# Scores: (min: 8, avg: 12.06060606060606, max: 46)
#
# Run: 67, exploration: 0.024741930939380097, score: 27
# Scores: (min: 8, avg: 12.283582089552239, max: 46)
#
# Run: 68, exploration: 0.023414639657910272, score: 12
# Scores: (min: 8, avg: 12.279411764705882, max: 46)
#
# Run: 69, exploration: 0.019450979052291272, score: 38
# Scores: (min: 8, avg: 12.652173913043478, max: 46)
#
# Run: 70, exploration: 0.01632109498333433, score: 36
# Scores: (min: 8, avg: 12.985714285714286, max: 46)
#
# Run: 71, exploration: 0.013832827362230486, score: 34
# Scores: (min: 8, avg: 13.28169014084507, max: 46)
#
# Run: 72, exploration: 0.01208186940302195, score: 28
# Scores: (min: 8, avg: 13.48611111111111, max: 46)
#
# Run: 73, exploration: 0.011094979641301777, score: 18
# Scores: (min: 8, avg: 13.547945205479452, max: 46)
#
# Run: 74, exploration: 0.010239902030817916, score: 17
# Scores: (min: 8, avg: 13.594594594594595, max: 46)
#
# Run: 75, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 13.893333333333333, max: 46)
#
# Run: 76, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 14.394736842105264, max: 52)
#
# Run: 77, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 15.766233766233766, max: 120)
#
# Run: 78, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 16.564102564102566, max: 120)
#
# Run: 79, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 16.89873417721519, max: 120)
#
# Run: 80, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 17, max: 120)
#
# Run: 81, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 17.28395061728395, max: 120)
#
# Run: 82, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 17.817073170731707, max: 120)
#
# Run: 83, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.72289156626506, max: 120)
#
# Run: 84, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 18.035714285714285, max: 120)
#
# Run: 85, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 18.305882352941175, max: 120)
#
# Run: 86, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 18.290697674418606, max: 120)
#
# Run: 87, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 18.32183908045977, max: 120)
#
# Run: 88, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 18.329545454545453, max: 120)
#
# Run: 89, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 18.50561797752809, max: 120)
#
# Run: 90, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 18.466666666666665, max: 120)
#
# Run: 91, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 18.395604395604394, max: 120)
#
# Run: 92, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 18.347826086956523, max: 120)
#
# Run: 93, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 18.623655913978496, max: 120)
#
# Run: 94, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 18.638297872340427, max: 120)
#
# Run: 95, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 18.568421052631578, max: 120)
#
# Run: 96, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 18.572916666666668, max: 120)
#
# Run: 97, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 18.701030927835053, max: 120)
#
# Run: 98, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 18.693877551020407, max: 120)
#
# Run: 99, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 18.67676767676768, max: 120)
#
# Run: 100, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 18.71, max: 120)
#
# Run: 101, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 18.83, max: 120)
#
# Run: 102, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 19.34, max: 120)
#
# Run: 103, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 19.47, max: 120)
#
# Run: 104, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 19.42, max: 120)
#
# Run: 105, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 19.81, max: 120)
#
# Run: 106, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 20.59, max: 120)
#
# Run: 107, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 21.12, max: 120)
#
# Run: 108, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 21.33, max: 120)
#
# Run: 109, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 21.53, max: 120)
#
# Run: 110, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 22.15, max: 120)
#
# Run: 111, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 22.29, max: 120)
#
# Run: 112, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 22.49, max: 120)
#
# Run: 113, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 23.63, max: 126)
#
# Run: 114, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 24.03, max: 126)
#
# Run: 115, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 24.15, max: 126)
#
# Run: 116, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 24.18, max: 126)
#
# Run: 117, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 24.23, max: 126)
#
# Run: 118, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 24.41, max: 126)
#
# Run: 119, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 24.52, max: 126)
#
# Run: 120, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 25.01, max: 126)
#
# Run: 121, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 25.05, max: 126)
#
# Run: 122, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 25.31, max: 126)
#
# Run: 123, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 25.37, max: 126)
#
# Run: 124, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 25.32, max: 126)
#
# Run: 125, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 25.37, max: 126)
#
# Run: 126, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 25.51, max: 126)
#
# Run: 127, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 25.61, max: 126)
#
# Run: 128, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 25.65, max: 126)
#
# Run: 129, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 25.7, max: 126)
#
# Run: 130, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 25.97, max: 126)
#
# Run: 131, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 26.14, max: 126)
#
# Run: 132, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 26.79, max: 126)
#
# Run: 133, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 27.03, max: 126)
#
# Run: 134, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 27.22, max: 126)
#
# Run: 135, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 27.67, max: 126)
#
# Run: 136, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 27.87, max: 126)
#
# Run: 137, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 27.88, max: 126)
#
# Run: 138, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 27.93, max: 126)
#
# Run: 139, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 28.24, max: 126)
#
# Run: 140, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 28.28, max: 126)
#
# Run: 141, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 29.53, max: 138)
#
# Run: 142, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 29.98, max: 138)
#
# Run: 143, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 30.79, max: 138)
#
# Run: 144, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 30.93, max: 138)
#
# Run: 145, exploration: 0.01, score: 75
# Scores: (min: 9, avg: 31.59, max: 138)
#
# Run: 146, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 32.54, max: 138)
#
# Run: 147, exploration: 0.01, score: 59
# Scores: (min: 9, avg: 33.03, max: 138)
#
# Run: 148, exploration: 0.01, score: 125
# Scores: (min: 9, avg: 34.18, max: 138)
#
# Run: 149, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 34.21, max: 138)
#
# Run: 150, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 34.23, max: 138)
#
# Run: 151, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 34.22, max: 138)
#
# Run: 152, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 34.21, max: 138)
#
# Run: 153, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 34.24, max: 138)
#
# Run: 154, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 35.23, max: 138)
#
# Run: 155, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 36.32, max: 138)
#
# Run: 156, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 36.71, max: 138)
#
# Run: 157, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 37.28, max: 138)
#
# Run: 158, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 38.33, max: 138)
#
# Run: 159, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 39.36, max: 138)
#
# Run: 160, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 39.58, max: 138)
#
# Run: 161, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 39.84, max: 138)
#
# Run: 162, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 40.8, max: 138)
#
# Run: 163, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 40.89, max: 138)
#
# Run: 164, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 41.54, max: 138)
#
# Run: 165, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 41.86, max: 138)
#
# Run: 166, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 41.87, max: 138)
#
# Run: 167, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 41.88, max: 138)
#
# Run: 168, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 42.83, max: 138)
#
# Run: 169, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 43.33, max: 138)
#
# Run: 170, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 43.86, max: 138)
#
# Run: 171, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 44.02, max: 138)
#
# Run: 172, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 43.91, max: 138)
#
# Run: 173, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 44.77, max: 138)
#
# Run: 174, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 44.72, max: 138)
#
# Run: 175, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 44.46, max: 138)
#
# Run: 176, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 44.27, max: 138)
#
# Run: 177, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 43.22, max: 138)
#
# Run: 178, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 43.34, max: 138)
#
# Run: 179, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 43.71, max: 138)
#
# Run: 180, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 43.56, max: 138)
#
# Run: 181, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 43.44, max: 138)
#
# Run: 182, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 42.94, max: 138)
#
# Run: 183, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 42.99, max: 138)
#
# Run: 184, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 42.71, max: 138)
#
# Run: 185, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 42.46, max: 138)
#
# Run: 186, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 42.52, max: 138)
#
# Run: 187, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 42.59, max: 138)
#
# Run: 188, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 43.28, max: 138)
#
# Run: 189, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 43.13, max: 138)
#
# Run: 190, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 43.11, max: 138)
#
# Run: 191, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 43.2, max: 138)
#
# Run: 192, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 44.23, max: 138)
#
# Run: 193, exploration: 0.01, score: 77
# Scores: (min: 8, avg: 44.56, max: 138)
#
# Run: 194, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 44.52, max: 138)
#
# Run: 195, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 44.77, max: 138)
#
# Run: 196, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 44.68, max: 138)
#
# Run: 197, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 44.72, max: 138)
#
# Run: 198, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 44.68, max: 138)
#
# Run: 199, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 45.18, max: 138)
#
# Run: 200, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 45.11, max: 138)
#
# Run: 201, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 45.16, max: 138)
#
# Run: 202, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 45.66, max: 138)
#
# Run: 203, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 46.43, max: 138)
#
# Run: 204, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 46.48, max: 138)
#
# Run: 205, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 45.88, max: 138)
#
# Run: 206, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 45.31, max: 138)
#
# Run: 207, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 44.88, max: 138)
#
# Run: 208, exploration: 0.01, score: 112
# Scores: (min: 8, avg: 45.66, max: 138)
#
# Run: 209, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 45.47, max: 138)
#
# Run: 210, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 44.81, max: 138)
#
# Run: 211, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 44.71, max: 138)
#
# Run: 212, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 44.47, max: 138)
#
# Run: 213, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 43.31, max: 138)
#
# Run: 214, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 42.9, max: 138)
#
# Run: 215, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 42.78, max: 138)
#
# Run: 216, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 42.77, max: 138)
#
# Run: 217, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 42.68, max: 138)
#
# Run: 218, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 42.48, max: 138)
#
# Run: 219, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 42.36, max: 138)
#
# Run: 220, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 41.85, max: 138)
#
# Run: 221, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 41.81, max: 138)
#
# Run: 222, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 41.63, max: 138)
#
# Run: 223, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 41.99, max: 138)
#
# Run: 224, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 42.55, max: 138)
#
# Run: 225, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 43.1, max: 138)
#
# Run: 226, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 43.22, max: 138)
#
# Run: 227, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 43.14, max: 138)
#
# Run: 228, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 43.1, max: 138)
#
# Run: 229, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 43.05, max: 138)
#
# Run: 230, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 43.48, max: 138)
#
# Run: 231, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 43.35, max: 138)
#
# Run: 232, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 42.6, max: 138)
#
# Run: 233, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 42.72, max: 138)
#
# Run: 234, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 42.78, max: 138)
#
# Run: 235, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 42.43, max: 138)
#
# Run: 236, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 42.56, max: 138)
#
# Run: 237, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 42.45, max: 138)
#
# Run: 238, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 42.42, max: 138)
#
# Run: 239, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 42.19, max: 138)
#
# Run: 240, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 42.19, max: 138)
#
# Run: 241, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 41.43, max: 125)
#
# Run: 242, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 41.07, max: 125)
#
# Run: 243, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 40.28, max: 125)
#
# Run: 244, exploration: 0.01, score: 77
# Scores: (min: 8, avg: 40.83, max: 125)
#
# Run: 245, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 40.68, max: 125)
#
# Run: 246, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 39.83, max: 125)
#
# Run: 247, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 39.4, max: 125)
#
# Run: 248, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 38.36, max: 125)
#
# Run: 249, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 38.36, max: 125)
#
# Run: 250, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 38.52, max: 125)
#
# Run: 251, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 38.62, max: 125)
#
# Run: 252, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 38.9, max: 125)
#
# Run: 253, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 38.93, max: 125)
#
# Run: 254, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 37.97, max: 125)
#
# Run: 255, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 36.88, max: 125)
#
# Run: 256, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 36.59, max: 125)
#
# Run: 257, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 36.08, max: 125)
#
# Run: 258, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 35.12, max: 125)
#
# Run: 259, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 34.15, max: 125)
#
# Run: 260, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 33.98, max: 125)
#
# Run: 261, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 33.88, max: 125)
#
# Run: 262, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 32.98, max: 125)
#
# Run: 263, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 33.03, max: 125)
#
# Run: 264, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 32.41, max: 125)
#
# Run: 265, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 32.13, max: 125)
#
# Run: 266, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 32.31, max: 125)
#
# Run: 267, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 32.19, max: 125)
#
# Run: 268, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 31.32, max: 125)
#
# Run: 269, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 30.59, max: 125)
#
# Run: 270, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 30.04, max: 125)
#
# Run: 271, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 29.71, max: 125)
#
# Run: 272, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 29.89, max: 125)
#
# Run: 273, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 29.03, max: 125)
#
# Run: 274, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 29.1, max: 125)
#
# Run: 275, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 29.21, max: 125)
#
# Run: 276, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 29.17, max: 125)
#
# Run: 277, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 29.45, max: 125)
#
# Run: 278, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 28.75, max: 125)
#
# Run: 279, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 28.19, max: 125)
#
# Run: 280, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 28.46, max: 125)
#
# Run: 281, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 28.48, max: 125)
#
# Run: 282, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 28.61, max: 125)
#
# Run: 283, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 28.74, max: 125)
#
# Run: 284, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 28.78, max: 125)
#
# Run: 285, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 28.88, max: 125)
#
# Run: 286, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 28.75, max: 125)
#
# Run: 287, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 28.65, max: 125)
#
# Run: 288, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 27.9, max: 125)
#
# Run: 289, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 27.89, max: 125)
#
# Run: 290, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 27.96, max: 125)
#
# Run: 291, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 27.86, max: 125)
#
# Run: 292, exploration: 0.01, score: 52
# Scores: (min: 9, avg: 27.21, max: 125)
#
# Run: 293, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 26.56, max: 125)
#
# Run: 294, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 26.62, max: 125)
#
# Run: 295, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 26.38, max: 125)
#
# Run: 296, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 26.57, max: 125)
#
# Run: 297, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 26.44, max: 125)
#
# Run: 298, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 26.51, max: 125)
#
# Run: 299, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 25.99, max: 125)
#
# Run: 300, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 26.12, max: 125)
#
# Run: 301, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 25.97, max: 125)
#
# Run: 302, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 24.99, max: 112)
#
# Run: 303, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 24.21, max: 112)
#
# Run: 304, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 24.21, max: 112)
#
# Run: 305, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 24.12, max: 112)
#
# Run: 306, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 23.85, max: 112)
#
# Run: 307, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 23.83, max: 112)
#
# Run: 308, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 23.14, max: 78)
#
# Run: 309, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 23.31, max: 78)
#
# Run: 310, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 23.39, max: 78)
#
# Run: 311, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 23.44, max: 78)
#
# Run: 312, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 23.5, max: 78)
#
# Run: 313, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 23.69, max: 78)
#
# Run: 314, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 23.91, max: 78)
#
# Run: 315, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 24.05, max: 78)
#
# Run: 316, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 24.12, max: 78)
#
# Run: 317, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 24.18, max: 78)
#
# Run: 318, exploration: 0.01, score: 57
# Scores: (min: 9, avg: 24.65, max: 78)
#
# Run: 319, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 24.66, max: 78)
#
# Run: 320, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 24.83, max: 78)
#
# Run: 321, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 24.96, max: 78)
#
# Run: 322, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 25, max: 78)
#
# Run: 323, exploration: 0.01, score: 41
# Scores: (min: 9, avg: 24.89, max: 78)
#
# Run: 324, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 24.58, max: 78)
#
# Run: 325, exploration: 0.01, score: 45
# Scores: (min: 9, avg: 24.32, max: 78)
#
# Run: 326, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 24.16, max: 78)
#
# Run: 327, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 24.41, max: 78)
#
# Run: 328, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 24.65, max: 78)
#
# Run: 329, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 24.75, max: 78)
#
# Run: 330, exploration: 0.01, score: 75
# Scores: (min: 9, avg: 24.72, max: 77)
#
# Run: 331, exploration: 0.01, score: 45
# Scores: (min: 9, avg: 24.98, max: 77)
#
# Run: 332, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 25.07, max: 77)
#
# Run: 333, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 24.69, max: 77)
#
# Run: 334, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 24.49, max: 77)
#
# Run: 335, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 24.45, max: 77)
#
# Run: 336, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 24.2, max: 77)
#
# Run: 337, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 24.17, max: 77)
#
# Run: 338, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 24.37, max: 77)
#
# Run: 339, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 24.38, max: 77)
#
# Run: 340, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 24.54, max: 77)
#
# Run: 341, exploration: 0.01, score: 51
# Scores: (min: 9, avg: 24.43, max: 77)
#
# Run: 342, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 24.39, max: 77)
#
# Run: 343, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 24.43, max: 77)
#
# Run: 344, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 23.85, max: 75)
#
# Run: 345, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 23.61, max: 75)
#
# Run: 346, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 23.57, max: 75)
#
# Run: 347, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 23.61, max: 75)
#
# Run: 348, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 23.6, max: 75)
#
# Run: 349, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 23.81, max: 75)
#
# Run: 350, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 23.75, max: 75)
#
# Run: 351, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 23.7, max: 75)
#
# Run: 352, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 23.48, max: 75)
#
# Run: 353, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 23.58, max: 75)
#
# Run: 354, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 23.59, max: 75)
#
# Run: 355, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 23.66, max: 75)
#
# Run: 356, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 23.56, max: 75)
#
# Run: 357, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 23.51, max: 75)
#
# Run: 358, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 23.42, max: 75)
#
# Run: 359, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 23.34, max: 75)
#
# Run: 360, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 23.28, max: 75)
#
# Run: 361, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 23.11, max: 75)
#
# Run: 362, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 23.03, max: 75)
#
# Run: 363, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 22.88, max: 75)
#
# Run: 364, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.84, max: 75)
#
# Run: 365, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 22.81, max: 75)
#
# Run: 366, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.61, max: 75)
#
# Run: 367, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 22.56, max: 75)
#
# Run: 368, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.46, max: 75)
#
# Run: 369, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.41, max: 75)
#
# Run: 370, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.17, max: 75)
#
# Run: 371, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.09, max: 75)
#
# Run: 372, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.83, max: 75)
#
# Run: 373, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 21.73, max: 75)
#
# Run: 374, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.63, max: 75)
#
# Run: 375, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.51, max: 75)
#
# Run: 376, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.32, max: 75)
#
# Run: 377, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.99, max: 75)
#
# Run: 378, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.88, max: 75)
#
# Run: 379, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.73, max: 75)
#
# Run: 380, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.46, max: 75)
#
# Run: 381, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 20.24, max: 75)
#
# Run: 382, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.09, max: 75)
#
# Run: 383, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.91, max: 75)
#
# Run: 384, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 19.79, max: 75)
#
# Run: 385, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.62, max: 75)
#
# Run: 386, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.62, max: 75)
#
# Run: 387, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.53, max: 75)
#
# Run: 388, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.5, max: 75)
#
# Run: 389, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.42, max: 75)
#
# Run: 390, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.31, max: 75)
#
# Run: 391, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.3, max: 75)
#
# Run: 392, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.88, max: 75)
#
# Run: 393, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.86, max: 75)
#
# Run: 394, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.73, max: 75)
#
# Run: 395, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.69, max: 75)
#
# Run: 396, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.49, max: 75)
#
# Run: 397, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.36, max: 75)
#
# Run: 398, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.25, max: 75)
#
# Run: 399, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.2, max: 75)
#
# Run: 400, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.01, max: 75)
#
# Run: 401, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.96, max: 75)
#
# Run: 402, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.78, max: 75)
#
# Run: 403, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.67, max: 75)
#
# Run: 404, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.58, max: 75)
#
# Run: 405, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.51, max: 75)
#
# Run: 406, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.44, max: 75)
#
# Run: 407, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.36, max: 75)
#
# Run: 408, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.02, max: 75)
#
# Run: 409, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.82, max: 75)
#
# Run: 410, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.74, max: 75)
#
# Run: 411, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.66, max: 75)
#
# Run: 412, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.6, max: 75)
#
# Run: 413, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.4, max: 75)
#
# Run: 414, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.18, max: 75)
#
# Run: 415, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.04, max: 75)
#
# Run: 416, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 15.87, max: 75)
#
# Run: 417, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.82, max: 75)
#
# Run: 418, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.34, max: 75)
#
# Run: 419, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 15.31, max: 75)
#
# Run: 420, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 15.11, max: 75)
#
# Run: 421, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.96, max: 75)
#
# Run: 422, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.84, max: 75)
#
# Run: 423, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.53, max: 75)
#
# Run: 424, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.27, max: 75)
#
# Run: 425, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.92, max: 75)
#
# Run: 426, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.79, max: 75)
#
# Run: 427, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.54, max: 75)
#
# Run: 428, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.28, max: 75)
#
# Run: 429, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.16, max: 75)
#
# Run: 430, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.52, max: 51)
#
# Run: 431, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.16, max: 51)
#
# Run: 432, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.09, max: 51)
#
# Run: 433, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.06, max: 51)
#
# Run: 434, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.99, max: 51)
#
# Run: 435, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.92, max: 51)
#
# Run: 436, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.82, max: 51)
#
# Run: 437, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.75, max: 51)
#
# Run: 438, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.52, max: 51)
#
# Run: 439, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.43, max: 51)
#
# Run: 440, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.22, max: 51)
#
# Run: 441, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.79, max: 36)
#
# Run: 442, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.75, max: 36)
#
# Run: 443, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.71, max: 36)
#
# Run: 444, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.62, max: 36)
#
# Run: 445, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.35, max: 33)
#
# Run: 446, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.28, max: 33)
#
# Run: 447, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.18, max: 33)
#
# Run: 448, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.07, max: 33)
#
# Run: 449, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.82, max: 25)
#
# Run: 450, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.69, max: 25)
#
# Run: 451, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.65, max: 25)
#
# Run: 452, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.6, max: 25)
#
# Run: 453, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.45, max: 16)
#
# Run: 454, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.41, max: 16)
#
# Run: 455, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.33, max: 11)
#
# Run: 456, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.32, max: 11)
#
# Run: 457, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.32, max: 11)
#
# Run: 458, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.32, max: 11)
#
# Run: 459, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.31, max: 11)
#
# Run: 460, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.32, max: 11)
#
# Run: 461, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.34, max: 11)
#
# Run: 462, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.36, max: 11)
#
# Run: 463, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.38, max: 11)
#
# Run: 464, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.37, max: 11)
#
# Run: 465, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.36, max: 11)
#
# Run: 466, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.35, max: 11)
#
# Run: 467, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.33, max: 11)
#
# Run: 468, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.31, max: 11)
#
# Run: 469, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.29, max: 11)
#
# Run: 470, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.28, max: 11)
#
# Run: 471, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.29, max: 11)
#
# Run: 472, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.29, max: 11)
#
# Run: 473, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.31, max: 11)
#
# Run: 474, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 9.35, max: 13)
#
# Run: 475, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.36, max: 13)
#
# Run: 476, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 9.41, max: 15)
#
# Run: 477, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 9.45, max: 15)
#
# Run: 478, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 9.52, max: 16)
#
# Run: 479, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 9.61, max: 18)
#
# Run: 480, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 9.63, max: 18)
#
# Run: 481, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 9.69, max: 18)
#
# Run: 482, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.69, max: 18)
#
# Run: 483, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 9.81, max: 22)
#
# Run: 484, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 9.85, max: 22)
#
# Run: 485, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.85, max: 22)
#
# Run: 486, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 9.9, max: 22)
#
# Run: 487, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.91, max: 22)
#
# Run: 488, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.91, max: 22)
#
# Run: 489, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 10.11, max: 30)
#
# Run: 490, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 10.17, max: 30)
#
# Run: 491, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.21, max: 30)
#
# Run: 492, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 10.35, max: 30)
#
# Run: 493, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 10.52, max: 30)
#
# Run: 494, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.54, max: 30)
#
# Run: 495, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 10.61, max: 30)
#
# Run: 496, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.64, max: 30)
#
# Run: 497, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 10.99, max: 44)
#
# Run: 498, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 11.12, max: 44)
#
# Run: 499, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.12, max: 44)
#
# Run: 500, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.14, max: 44)
#
# Run: 501, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.19, max: 44)
#
# Run: 502, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.23, max: 44)
#
# Run: 503, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.22, max: 44)
#
# Run: 504, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 11.36, max: 44)
#
# Run: 505, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 11.46, max: 44)
#
# Run: 506, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 11.56, max: 44)
#
# Run: 507, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.62, max: 44)
#
# Run: 508, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 11.74, max: 44)
#
# Run: 509, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 11.9, max: 44)
#
# Run: 510, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.95, max: 44)
#
# Run: 511, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.97, max: 44)
#
# Run: 512, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 12.1, max: 44)
#
# Run: 513, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 12.19, max: 44)
#
# Run: 514, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.19, max: 44)
#
# Run: 515, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 12.37, max: 44)
#
# Run: 516, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.42, max: 44)
#
# Run: 517, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 12.5, max: 44)
#
# Run: 518, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.52, max: 44)
#
# Run: 519, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.59, max: 44)
#
# Run: 520, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 12.7, max: 44)
#
# Run: 521, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 12.88, max: 44)
#
# Run: 522, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.91, max: 44)
#
# Run: 523, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 13.06, max: 44)
#
# Run: 524, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 13.15, max: 44)
#
# Run: 525, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.16, max: 44)
#
# Run: 526, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 13.25, max: 44)
#
# Run: 527, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 13.4, max: 44)
#
# Run: 528, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.43, max: 44)
#
# Run: 529, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 13.65, max: 44)
#
# Run: 530, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.67, max: 44)
#
# Run: 531, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.71, max: 44)
#
# Run: 532, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 13.8, max: 44)
#
# Run: 533, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.81, max: 44)
#
# Run: 534, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 13.88, max: 44)
#
# Run: 535, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 13.93, max: 44)
#
# Run: 536, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 13.99, max: 44)
#
# Run: 537, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 14.12, max: 44)
#
# Run: 538, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.15, max: 44)
#
# Run: 539, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 14.29, max: 44)
#
# Run: 540, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.35, max: 44)
#
# Run: 541, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 14.55, max: 44)
#
# Run: 542, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.55, max: 44)
#
# Run: 543, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.55, max: 44)
#
# Run: 544, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.54, max: 44)
#
# Run: 545, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.54, max: 44)
#
# Run: 546, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.55, max: 44)
#
# Run: 547, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.55, max: 44)
#
# Run: 548, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.55, max: 44)
#
# Run: 549, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.56, max: 44)
#
# Run: 550, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.56, max: 44)
#
# Run: 551, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.56, max: 44)
#
# Run: 552, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.57, max: 44)
#
# Run: 553, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.56, max: 44)
#
# Run: 554, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.55, max: 44)
#
# Run: 555, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.56, max: 44)
#
# Run: 556, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.57, max: 44)
#
# Run: 557, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.56, max: 44)
#
# Run: 558, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.55, max: 44)
#
# Run: 559, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.57, max: 44)
#
# Run: 560, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.56, max: 44)
#
# Run: 561, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.54, max: 44)
#
# Run: 562, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.54, max: 44)
#
# Run: 563, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.54, max: 44)
#
# Run: 564, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.55, max: 44)
#
# Run: 565, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.55, max: 44)
#
# Run: 566, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.56, max: 44)
#
# Run: 567, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.57, max: 44)
#
# Run: 568, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.59, max: 44)
#
# Run: 569, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.61, max: 44)
#
# Run: 570, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.61, max: 44)
#
# Run: 571, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.59, max: 44)
#
# Run: 572, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.6, max: 44)
#
# Run: 573, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.59, max: 44)
#
# Run: 574, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.55, max: 44)
#
# Run: 575, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.54, max: 44)
#
# Run: 576, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.48, max: 44)
#
# Run: 577, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.43, max: 44)
#
# Run: 578, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.42, max: 44)
#
# Run: 579, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 14.56, max: 44)
#
# Run: 580, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.54, max: 44)
#
# Run: 581, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.48, max: 44)
#
# Run: 582, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 14.67, max: 44)
#
# Run: 583, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.57, max: 44)
#
# Run: 584, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.55, max: 44)
#
# Run: 585, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.56, max: 44)
#
# Run: 586, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 14.67, max: 44)
#
# Run: 587, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.67, max: 44)
#
# Run: 588, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.68, max: 44)
#
# Run: 589, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 14.57, max: 44)
#
# ...
#
# Run: 10639, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.78, max: 63)
#
# Run: 10640, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.8, max: 63)
#
# Run: 10641, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 16.75, max: 63)
#
# Run: 10642, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.41, max: 63)
#
# Run: 10643, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.36, max: 63)
#
# Run: 10644, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.36, max: 63)
#
# Run: 10645, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.25, max: 63)
#
# Run: 10646, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.16, max: 63)
#
# Run: 10647, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 16.26, max: 63)
#
# Run: 10648, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.2, max: 63)
#
# Run: 10649, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.25, max: 63)
#
# Run: 10650, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 16.09, max: 63)
#
# Run: 10651, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 16.14, max: 63)
#
# Run: 10652, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 16.33, max: 63)
#
# Run: 10653, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.35, max: 63)
#
# Run: 10654, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 16.24, max: 63)
#
# Run: 10655, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.09, max: 63)
#
# Run: 10656, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 15.83, max: 44)
#
# Run: 10657, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 16.14, max: 45)
#
# Run: 10658, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 16.33, max: 45)
#
# Run: 10659, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.17, max: 45)
#
# Run: 10660, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.21, max: 45)
#
# Run: 10661, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16.27, max: 45)
#
# Run: 10662, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.17, max: 45)
#
# Run: 10663, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.13, max: 45)
#
# Run: 10664, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 16.22, max: 45)
#
# Run: 10665, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 16.04, max: 45)
#
# Run: 10666, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 16.16, max: 45)
#
# Run: 10667, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.16, max: 45)
#
# Run: 10668, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.18, max: 45)
#
# Run: 10669, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 16.17, max: 45)
#
# Run: 10670, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.19, max: 45)
#
# Run: 10671, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.25, max: 45)
#
# Run: 10672, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 16.33, max: 45)
#
# Run: 10673, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.33, max: 45)
#
# Run: 10674, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.33, max: 45)
#
# Run: 10675, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 16.5, max: 45)
#
# Run: 10676, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.48, max: 45)
#
# Run: 10677, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.45, max: 45)
#
# Run: 10678, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 16.55, max: 45)
#
# Run: 10679, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 16.67, max: 45)
#
# Run: 10680, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.68, max: 45)
#
# Run: 10681, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.46, max: 45)
#
# Run: 10682, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.46, max: 45)
#
# Run: 10683, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 16.57, max: 45)
#
# Run: 10684, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 16.59, max: 45)
#
# Run: 10685, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.55, max: 45)
#
# Run: 10686, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16.5, max: 45)
#
# Run: 10687, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.53, max: 45)
#
# Run: 10688, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 16.56, max: 45)
#
# Run: 10689, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.58, max: 45)
#
# Run: 10690, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 16.64, max: 45)
#
# Run: 10691, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.59, max: 45)
#
# Run: 10692, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 16.55, max: 45)
#
# Run: 10693, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.57, max: 45)
#
# Run: 10694, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.59, max: 45)
#
# Run: 10695, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 16.61, max: 45)
#
# Run: 10696, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.64, max: 45)
#
# Run: 10697, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.3, max: 45)
#
# Run: 10698, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.3, max: 45)
#
# Run: 10699, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.15, max: 45)
#
# Run: 10700, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16.12, max: 45)
#
# Run: 10701, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.84, max: 45)
#
# Run: 10702, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.83, max: 45)
#
# Run: 10703, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 15.86, max: 45)
#
# Run: 10704, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.85, max: 45)
#
# Run: 10705, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.86, max: 45)
#
# Run: 10706, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.85, max: 45)
#
# Run: 10707, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.84, max: 45)
#
# Run: 10708, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.67, max: 45)
#
# Run: 10709, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.7, max: 45)
#
# Run: 10710, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 15.6, max: 45)
#
# Run: 10711, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.53, max: 45)
#
# Run: 10712, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 15.38, max: 45)
#
# Run: 10713, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.36, max: 45)
#
# Run: 10714, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.36, max: 45)
#
# Run: 10715, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 15.47, max: 45)
#
# Run: 10716, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 15.57, max: 45)
#
# Run: 10717, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 15.52, max: 45)
#
# Run: 10718, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 15.63, max: 45)
#
# Run: 10719, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.41, max: 45)
#
# Run: 10720, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 15.19, max: 45)
#
# Run: 10721, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.18, max: 45)
#
# Run: 10722, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.08, max: 45)
#
# Run: 10723, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 15.14, max: 45)
#
# Run: 10724, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.12, max: 45)
#
# Run: 10725, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 15.21, max: 45)
#
# Run: 10726, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.2, max: 45)
#
# Run: 10727, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 15.26, max: 45)
#
# Run: 10728, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.19, max: 45)
#
# Run: 10729, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 15.24, max: 45)
#
# Run: 10730, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.27, max: 45)
#
# Run: 10731, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.24, max: 45)
#
# Run: 10732, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 15.15, max: 45)
#
# Run: 10733, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 15.3, max: 45)
#
# Run: 10734, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.27, max: 45)
#
# Run: 10735, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.11, max: 45)
#
# Run: 10736, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.03, max: 45)
#
# Run: 10737, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.05, max: 45)
#
# Run: 10738, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 15.23, max: 45)
#
# Run: 10739, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 15.22, max: 45)
#
# Run: 10740, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 15.39, max: 45)
#
# Run: 10741, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.42, max: 45)
#
# Run: 10742, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.44, max: 45)
#
# Run: 10743, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 15.6, max: 45)
#
# Run: 10744, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.62, max: 45)
#
# Run: 10745, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 15.67, max: 45)
#
# Run: 10746, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.66, max: 45)
#
# Run: 10747, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.56, max: 45)
#
# Run: 10748, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.55, max: 45)
#
# Run: 10749, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 15.49, max: 45)
#
# Run: 10750, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.43, max: 45)
#
# Run: 10751, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.31, max: 45)
#
# Run: 10752, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.15, max: 45)
#
# Run: 10753, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 15.2, max: 45)
#
# Run: 10754, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.96, max: 45)
#
# Run: 10755, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.97, max: 45)
#
# Run: 10756, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 15.05, max: 45)
#
# Run: 10757, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.69, max: 45)
#
# Run: 10758, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.54, max: 45)
#
# Run: 10759, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.53, max: 45)
#
# Run: 10760, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.51, max: 45)
#
# Run: 10761, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.45, max: 45)
#
# Run: 10762, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 14.49, max: 45)
#
# Run: 10763, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 14.58, max: 45)
#
# Run: 10764, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 14.79, max: 45)
#
# Run: 10765, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.83, max: 45)
#
# Run: 10766, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 14.9, max: 45)
#
# Run: 10767, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 14.9, max: 45)
#
# Run: 10768, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.9, max: 45)
#
# Run: 10769, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.92, max: 45)
#
# Run: 10770, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.91, max: 45)
#
# Run: 10771, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 15.08, max: 45)
#
# Run: 10772, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 15.09, max: 45)
#
# Run: 10773, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.09, max: 45)
#
# Run: 10774, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.09, max: 45)
#
# Run: 10775, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.91, max: 45)
#
# Run: 10776, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 15.14, max: 45)
#
# Run: 10777, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.16, max: 45)
#
# Run: 10778, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.07, max: 45)
#
# Run: 10779, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.83, max: 45)
#
# Run: 10780, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.84, max: 45)
#
# Run: 10781, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.8, max: 45)
#
# Run: 10782, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.82, max: 45)
#
# Run: 10783, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.73, max: 45)
#
# Run: 10784, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.7, max: 45)
#
# Run: 10785, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 14.79, max: 45)
#
# Run: 10786, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.73, max: 45)
#
# Run: 10787, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.69, max: 45)
#
# Run: 10788, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.57, max: 45)
#
# Run: 10789, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 14.7, max: 45)
#
# Run: 10790, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.63, max: 45)
#
# Run: 10791, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 14.68, max: 45)
#
# Run: 10792, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.69, max: 45)
#
# Run: 10793, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.66, max: 45)
#
# Run: 10794, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.63, max: 45)
#
# Run: 10795, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.54, max: 45)
#
# Run: 10796, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.53, max: 45)
#
# Run: 10797, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.54, max: 45)
#
# Run: 10798, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.56, max: 45)
#
# Run: 10799, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 14.73, max: 45)
#
# Run: 10800, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.65, max: 45)
#
# Run: 10801, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.61, max: 45)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-5fb09ab97e5c> in <module>
#       1 # changed learning rate from 0.001 to 0.01
# ----> 2 cartpole()
#
# <ipython-input-3-7736b17c7e1e> in cartpole()
#      85                 score_logger.add_score(step, run)
#      86                 break
# ---> 87             dqn_solver.experience_replay()
#
# <ipython-input-3-7736b17c7e1e> in experience_replay(self)
#      52             q_update = reward
#      53             if not terminal:
# ---> 54                 q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
#      55             q_values = self.model.predict(state)
#      56             q_values[0][action] = q_update
#
# c:\Users\prest\Desktop\College_Programing\CS-370-Current_Emerging_Trends_in_CS\venv\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# c:\Users\prest\Desktop\College_Programing\CS-370-Current_Emerging_Trends_in_CS\venv\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# c:\Users\prest\Desktop\College_Programing\CS-370-Current_Emerging_Trends_in_CS\venv\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3733     return nest.pack_sequence_as(
#    3734         self._outputs_structure,
# -> 3735         [x._numpy() for x in outputs],  # pylint: disable=protected-access
#    3736         expand_composites=True)
#    3737
#
# c:\Users\prest\Desktop\College_Programing\CS-370-Current_Emerging_Trends_in_CS\venv\lib\site-packages\tensorflow_core\python\keras\backend.py in <listcomp>(.0)
#    3733     return nest.pack_sequence_as(
#    3734         self._outputs_structure,
# -> 3735         [x._numpy() for x in outputs],  # pylint: disable=protected-access
#    3736         expand_composites=True)
#    3737
#
# c:\Users\prest\Desktop\College_Programing\CS-370-Current_Emerging_Trends_in_CS\venv\lib\site-packages\tensorflow_core\python\framework\ops.py in _numpy(self)
#     906     # pylint: disable=protected-access
#     907     try:
# --> 908       return self._numpy_internal()
#     909     except core._NotOkStatusException as e:
#     910       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:

# %% [markdown]
# I stopped the above run after letting it go for the entire time I was at work. The script ran for ~10 hours and was nowhere near close to solving the problem even after 10k+ runs.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  

from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"
  
GAMMA = 0.5     # changed discount factor from 0.95 to 0.5
LEARNING_RATE = 0.001
  
MEMORY_SIZE = 1000000
BATCH_SIZE = 20
  
EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.01
EXPLORATION_DECAY = 0.995
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
# changed discount factor from 0.95 to 0.5
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 17
# Scores: (min: 17, avg: 17, max: 17)
#
# Run: 2, exploration: 0.9137248860125932, score: 21
# Scores: (min: 17, avg: 19, max: 21)
#
# Run: 3, exploration: 0.7255664080186093, score: 47
# Scores: (min: 17, avg: 28.333333333333332, max: 47)
#
# Run: 4, exploration: 0.6696478204705644, score: 17
# Scores: (min: 17, avg: 25.5, max: 47)
#
# Run: 5, exploration: 0.5997278763867329, score: 23
# Scores: (min: 17, avg: 25, max: 47)
#
# Run: 6, exploration: 0.5344229416520513, score: 24
# Scores: (min: 17, avg: 24.833333333333332, max: 47)
#
# Run: 7, exploration: 0.4351424010585501, score: 42
# Scores: (min: 17, avg: 27.285714285714285, max: 47)
#
# Run: 8, exploration: 0.40974000909221303, score: 13
# Scores: (min: 13, avg: 25.5, max: 47)
#
# Run: 9, exploration: 0.3386767948568688, score: 39
# Scores: (min: 13, avg: 27, max: 47)
#
# Run: 10, exploration: 0.28993519966087045, score: 32
# Scores: (min: 13, avg: 27.5, max: 47)
#
# Run: 11, exploration: 0.23489314109365644, score: 43
# Scores: (min: 13, avg: 28.90909090909091, max: 47)
#
# Run: 12, exploration: 0.19908200231898848, score: 34
# Scores: (min: 13, avg: 29.333333333333332, max: 47)
#
# Run: 13, exploration: 0.16048131420416054, score: 44
# Scores: (min: 13, avg: 30.46153846153846, max: 47)
#
# Run: 14, exploration: 0.1313250884614265, score: 41
# Scores: (min: 13, avg: 31.214285714285715, max: 47)
#
# Run: 15, exploration: 0.12242520289863423, score: 15
# Scores: (min: 13, avg: 30.133333333333333, max: 47)
#
# Run: 16, exploration: 0.10533270926593409, score: 31
# Scores: (min: 13, avg: 30.1875, max: 47)
#
# Run: 17, exploration: 0.08576489601717459, score: 42
# Scores: (min: 13, avg: 30.88235294117647, max: 47)
#
# Run: 18, exploration: 0.06380744126877576, score: 60
# Scores: (min: 13, avg: 32.5, max: 60)
#
# Run: 19, exploration: 0.05143559895690903, score: 44
# Scores: (min: 13, avg: 33.10526315789474, max: 60)
#
# Run: 20, exploration: 0.0418803316354751, score: 42
# Scores: (min: 13, avg: 33.55, max: 60)
#
# Run: 21, exploration: 0.03308985827710748, score: 48
# Scores: (min: 13, avg: 34.23809523809524, max: 60)
#
# Run: 22, exploration: 0.020348562734319765, score: 98
# Scores: (min: 13, avg: 37.13636363636363, max: 98)
#
# Run: 23, exploration: 0.01, score: 146
# Scores: (min: 13, avg: 41.869565217391305, max: 146)
#
# Run: 24, exploration: 0.01, score: 67
# Scores: (min: 13, avg: 42.916666666666664, max: 146)
#
# Run: 25, exploration: 0.01, score: 254
# Scores: (min: 13, avg: 51.36, max: 254)
#
# Run: 26, exploration: 0.01, score: 34
# Scores: (min: 13, avg: 50.69230769230769, max: 254)
#
# Run: 27, exploration: 0.01, score: 30
# Scores: (min: 13, avg: 49.925925925925924, max: 254)
#
# Run: 28, exploration: 0.01, score: 305
# Scores: (min: 13, avg: 59.035714285714285, max: 305)
#
# Run: 29, exploration: 0.01, score: 111
# Scores: (min: 13, avg: 60.827586206896555, max: 305)
#
# Run: 30, exploration: 0.01, score: 44
# Scores: (min: 13, avg: 60.266666666666666, max: 305)
#
# Run: 31, exploration: 0.01, score: 119
# Scores: (min: 13, avg: 62.16129032258065, max: 305)
#
# Run: 32, exploration: 0.01, score: 76
# Scores: (min: 13, avg: 62.59375, max: 305)
#
# Run: 33, exploration: 0.01, score: 102
# Scores: (min: 13, avg: 63.78787878787879, max: 305)
#
# Run: 34, exploration: 0.01, score: 101
# Scores: (min: 13, avg: 64.88235294117646, max: 305)
#
# Run: 35, exploration: 0.01, score: 18
# Scores: (min: 13, avg: 63.542857142857144, max: 305)
#
# Run: 36, exploration: 0.01, score: 57
# Scores: (min: 13, avg: 63.361111111111114, max: 305)
#
# Run: 37, exploration: 0.01, score: 200
# Scores: (min: 13, avg: 67.05405405405405, max: 305)
#
# Run: 38, exploration: 0.01, score: 172
# Scores: (min: 13, avg: 69.8157894736842, max: 305)
#
# Run: 39, exploration: 0.01, score: 14
# Scores: (min: 13, avg: 68.38461538461539, max: 305)
#
# Run: 40, exploration: 0.01, score: 105
# Scores: (min: 13, avg: 69.3, max: 305)
#
# Run: 41, exploration: 0.01, score: 101
# Scores: (min: 13, avg: 70.07317073170732, max: 305)
#
# Run: 42, exploration: 0.01, score: 366
# Scores: (min: 13, avg: 77.11904761904762, max: 366)
#
# Run: 43, exploration: 0.01, score: 131
# Scores: (min: 13, avg: 78.37209302325581, max: 366)
#
# Run: 44, exploration: 0.01, score: 150
# Scores: (min: 13, avg: 80, max: 366)
#
# Run: 45, exploration: 0.01, score: 134
# Scores: (min: 13, avg: 81.2, max: 366)
#
# Run: 46, exploration: 0.01, score: 141
# Scores: (min: 13, avg: 82.5, max: 366)
#
# Run: 47, exploration: 0.01, score: 20
# Scores: (min: 13, avg: 81.17021276595744, max: 366)
#
# Run: 48, exploration: 0.01, score: 135
# Scores: (min: 13, avg: 82.29166666666667, max: 366)
#
# Run: 49, exploration: 0.01, score: 28
# Scores: (min: 13, avg: 81.18367346938776, max: 366)
#
# Run: 50, exploration: 0.01, score: 229
# Scores: (min: 13, avg: 84.14, max: 366)
#
# Run: 51, exploration: 0.01, score: 116
# Scores: (min: 13, avg: 84.76470588235294, max: 366)
#
# Run: 52, exploration: 0.01, score: 73
# Scores: (min: 13, avg: 84.53846153846153, max: 366)
#
# Run: 53, exploration: 0.01, score: 34
# Scores: (min: 13, avg: 83.58490566037736, max: 366)
#
# Run: 54, exploration: 0.01, score: 83
# Scores: (min: 13, avg: 83.57407407407408, max: 366)
#
# Run: 55, exploration: 0.01, score: 169
# Scores: (min: 13, avg: 85.12727272727273, max: 366)
#
# Run: 56, exploration: 0.01, score: 131
# Scores: (min: 13, avg: 85.94642857142857, max: 366)
#
# Run: 57, exploration: 0.01, score: 302
# Scores: (min: 13, avg: 89.73684210526316, max: 366)
#
# Run: 58, exploration: 0.01, score: 230
# Scores: (min: 13, avg: 92.15517241379311, max: 366)
#
# Run: 59, exploration: 0.01, score: 50
# Scores: (min: 13, avg: 91.44067796610169, max: 366)
#
# Run: 60, exploration: 0.01, score: 179
# Scores: (min: 13, avg: 92.9, max: 366)
#
# Run: 61, exploration: 0.01, score: 181
# Scores: (min: 13, avg: 94.34426229508196, max: 366)
#
# Run: 62, exploration: 0.01, score: 49
# Scores: (min: 13, avg: 93.61290322580645, max: 366)
#
# Run: 63, exploration: 0.01, score: 254
# Scores: (min: 13, avg: 96.15873015873017, max: 366)
#
# Run: 64, exploration: 0.01, score: 31
# Scores: (min: 13, avg: 95.140625, max: 366)
#
# Run: 65, exploration: 0.01, score: 225
# Scores: (min: 13, avg: 97.13846153846154, max: 366)
#
# Run: 66, exploration: 0.01, score: 75
# Scores: (min: 13, avg: 96.8030303030303, max: 366)
#
# Run: 67, exploration: 0.01, score: 158
# Scores: (min: 13, avg: 97.71641791044776, max: 366)
#
# Run: 68, exploration: 0.01, score: 114
# Scores: (min: 13, avg: 97.95588235294117, max: 366)
#
# Run: 69, exploration: 0.01, score: 229
# Scores: (min: 13, avg: 99.85507246376811, max: 366)
#
# Run: 70, exploration: 0.01, score: 242
# Scores: (min: 13, avg: 101.88571428571429, max: 366)
#
# Run: 71, exploration: 0.01, score: 237
# Scores: (min: 13, avg: 103.78873239436619, max: 366)
#
# Run: 72, exploration: 0.01, score: 92
# Scores: (min: 13, avg: 103.625, max: 366)
#
# Run: 73, exploration: 0.01, score: 52
# Scores: (min: 13, avg: 102.91780821917808, max: 366)
#
# Run: 74, exploration: 0.01, score: 191
# Scores: (min: 13, avg: 104.10810810810811, max: 366)
#
# Run: 75, exploration: 0.01, score: 89
# Scores: (min: 13, avg: 103.90666666666667, max: 366)
#
# Run: 76, exploration: 0.01, score: 141
# Scores: (min: 13, avg: 104.39473684210526, max: 366)
#
# Run: 77, exploration: 0.01, score: 247
# Scores: (min: 13, avg: 106.24675324675324, max: 366)
#
# Run: 78, exploration: 0.01, score: 121
# Scores: (min: 13, avg: 106.43589743589743, max: 366)
#
# Run: 79, exploration: 0.01, score: 191
# Scores: (min: 13, avg: 107.50632911392405, max: 366)
#
# Run: 80, exploration: 0.01, score: 173
# Scores: (min: 13, avg: 108.325, max: 366)
#
# Run: 81, exploration: 0.01, score: 236
# Scores: (min: 13, avg: 109.90123456790124, max: 366)
#
# Run: 82, exploration: 0.01, score: 104
# Scores: (min: 13, avg: 109.82926829268293, max: 366)
#
# Run: 83, exploration: 0.01, score: 275
# Scores: (min: 13, avg: 111.81927710843374, max: 366)
#
# Run: 84, exploration: 0.01, score: 172
# Scores: (min: 13, avg: 112.53571428571429, max: 366)
#
# Run: 85, exploration: 0.01, score: 95
# Scores: (min: 13, avg: 112.32941176470588, max: 366)
#
# Run: 86, exploration: 0.01, score: 213
# Scores: (min: 13, avg: 113.5, max: 366)
#
# Run: 87, exploration: 0.01, score: 50
# Scores: (min: 13, avg: 112.77011494252874, max: 366)
#
# Run: 88, exploration: 0.01, score: 363
# Scores: (min: 13, avg: 115.61363636363636, max: 366)
#
# Run: 89, exploration: 0.01, score: 121
# Scores: (min: 13, avg: 115.67415730337079, max: 366)
#
# Run: 90, exploration: 0.01, score: 277
# Scores: (min: 13, avg: 117.46666666666667, max: 366)
#
# Run: 91, exploration: 0.01, score: 376
# Scores: (min: 13, avg: 120.3076923076923, max: 376)
#
# Run: 92, exploration: 0.01, score: 55
# Scores: (min: 13, avg: 119.59782608695652, max: 376)
#
# Run: 93, exploration: 0.01, score: 29
# Scores: (min: 13, avg: 118.6236559139785, max: 376)
#
# Run: 94, exploration: 0.01, score: 127
# Scores: (min: 13, avg: 118.7127659574468, max: 376)
#
# Run: 95, exploration: 0.01, score: 113
# Scores: (min: 13, avg: 118.65263157894736, max: 376)
#
# Run: 96, exploration: 0.01, score: 336
# Scores: (min: 13, avg: 120.91666666666667, max: 376)
#
# Run: 97, exploration: 0.01, score: 104
# Scores: (min: 13, avg: 120.74226804123711, max: 376)
#
# Run: 98, exploration: 0.01, score: 98
# Scores: (min: 13, avg: 120.51020408163265, max: 376)
#
# Run: 99, exploration: 0.01, score: 68
# Scores: (min: 13, avg: 119.97979797979798, max: 376)
#
# Run: 100, exploration: 0.01, score: 36
# Scores: (min: 13, avg: 119.14, max: 376)
#
# Run: 101, exploration: 0.01, score: 60
# Scores: (min: 13, avg: 119.57, max: 376)
#
# Run: 102, exploration: 0.01, score: 154
# Scores: (min: 13, avg: 120.9, max: 376)
#
# Run: 103, exploration: 0.01, score: 167
# Scores: (min: 13, avg: 122.1, max: 376)
#
# Run: 104, exploration: 0.01, score: 86
# Scores: (min: 13, avg: 122.79, max: 376)
#
# Run: 105, exploration: 0.01, score: 310
# Scores: (min: 13, avg: 125.66, max: 376)
#
# Run: 106, exploration: 0.01, score: 170
# Scores: (min: 13, avg: 127.12, max: 376)
#
# Run: 107, exploration: 0.01, score: 227
# Scores: (min: 13, avg: 128.97, max: 376)
#
# Run: 108, exploration: 0.01, score: 80
# Scores: (min: 14, avg: 129.64, max: 376)
#
# Run: 109, exploration: 0.01, score: 23
# Scores: (min: 14, avg: 129.48, max: 376)
#
# Run: 110, exploration: 0.01, score: 47
# Scores: (min: 14, avg: 129.63, max: 376)
#
# Run: 111, exploration: 0.01, score: 155
# Scores: (min: 14, avg: 130.75, max: 376)
#
# Run: 112, exploration: 0.01, score: 35
# Scores: (min: 14, avg: 130.76, max: 376)
#
# Run: 113, exploration: 0.01, score: 285
# Scores: (min: 14, avg: 133.17, max: 376)
#
# Run: 114, exploration: 0.01, score: 87
# Scores: (min: 14, avg: 133.63, max: 376)
#
# Run: 115, exploration: 0.01, score: 59
# Scores: (min: 14, avg: 134.07, max: 376)
#
# Run: 116, exploration: 0.01, score: 181
# Scores: (min: 14, avg: 135.57, max: 376)
#
# Run: 117, exploration: 0.01, score: 126
# Scores: (min: 14, avg: 136.41, max: 376)
#
# Run: 118, exploration: 0.01, score: 53
# Scores: (min: 14, avg: 136.34, max: 376)
#
# Run: 119, exploration: 0.01, score: 55
# Scores: (min: 14, avg: 136.45, max: 376)
#
# Run: 120, exploration: 0.01, score: 50
# Scores: (min: 14, avg: 136.53, max: 376)
#
# Run: 121, exploration: 0.01, score: 71
# Scores: (min: 14, avg: 136.76, max: 376)
#
# Run: 122, exploration: 0.01, score: 111
# Scores: (min: 14, avg: 136.89, max: 376)
#
# Run: 123, exploration: 0.01, score: 349
# Scores: (min: 14, avg: 138.92, max: 376)
#
# Run: 124, exploration: 0.01, score: 123
# Scores: (min: 14, avg: 139.48, max: 376)
#
# Run: 125, exploration: 0.01, score: 236
# Scores: (min: 14, avg: 139.3, max: 376)
#
# Run: 126, exploration: 0.01, score: 128
# Scores: (min: 14, avg: 140.24, max: 376)
#
# Run: 127, exploration: 0.01, score: 65
# Scores: (min: 14, avg: 140.59, max: 376)
#
# Run: 128, exploration: 0.01, score: 126
# Scores: (min: 14, avg: 138.8, max: 376)
#
# Run: 129, exploration: 0.01, score: 47
# Scores: (min: 14, avg: 138.16, max: 376)
#
# Run: 130, exploration: 0.01, score: 99
# Scores: (min: 14, avg: 138.71, max: 376)
#
# Run: 131, exploration: 0.01, score: 179
# Scores: (min: 14, avg: 139.31, max: 376)
#
# Run: 132, exploration: 0.01, score: 111
# Scores: (min: 14, avg: 139.66, max: 376)
#
# Run: 133, exploration: 0.01, score: 124
# Scores: (min: 14, avg: 139.88, max: 376)
#
# Run: 134, exploration: 0.01, score: 290
# Scores: (min: 14, avg: 141.77, max: 376)
#
# Run: 135, exploration: 0.01, score: 34
# Scores: (min: 14, avg: 141.93, max: 376)
#
# Run: 136, exploration: 0.01, score: 64
# Scores: (min: 14, avg: 142, max: 376)
#
# Run: 137, exploration: 0.01, score: 54
# Scores: (min: 14, avg: 140.54, max: 376)
#
# Run: 138, exploration: 0.01, score: 51
# Scores: (min: 14, avg: 139.33, max: 376)
#
# Run: 139, exploration: 0.01, score: 62
# Scores: (min: 20, avg: 139.81, max: 376)
#
# Run: 140, exploration: 0.01, score: 53
# Scores: (min: 20, avg: 139.29, max: 376)
#
# Run: 141, exploration: 0.01, score: 151
# Scores: (min: 20, avg: 139.79, max: 376)
#
# Run: 142, exploration: 0.01, score: 95
# Scores: (min: 20, avg: 137.08, max: 376)
#
# Run: 143, exploration: 0.01, score: 213
# Scores: (min: 20, avg: 137.9, max: 376)
#
# Run: 144, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 136.51, max: 376)
#
# Run: 145, exploration: 0.01, score: 32
# Scores: (min: 11, avg: 135.49, max: 376)
#
# Run: 146, exploration: 0.01, score: 37
# Scores: (min: 11, avg: 134.45, max: 376)
#
# Run: 147, exploration: 0.01, score: 86
# Scores: (min: 11, avg: 135.11, max: 376)
#
# Run: 148, exploration: 0.01, score: 13
# Scores: (min: 11, avg: 133.89, max: 376)
#
# Run: 149, exploration: 0.01, score: 156
# Scores: (min: 11, avg: 135.17, max: 376)
#
# Run: 150, exploration: 0.01, score: 52
# Scores: (min: 11, avg: 133.4, max: 376)
#
# Run: 151, exploration: 0.01, score: 79
# Scores: (min: 11, avg: 133.03, max: 376)
#
# Run: 152, exploration: 0.01, score: 102
# Scores: (min: 11, avg: 133.32, max: 376)
#
# Run: 153, exploration: 0.01, score: 369
# Scores: (min: 11, avg: 136.67, max: 376)
#
# Run: 154, exploration: 0.01, score: 32
# Scores: (min: 11, avg: 136.16, max: 376)
#
# Run: 155, exploration: 0.01, score: 123
# Scores: (min: 11, avg: 135.7, max: 376)
#
# Run: 156, exploration: 0.01, score: 98
# Scores: (min: 11, avg: 135.37, max: 376)
#
# Run: 157, exploration: 0.01, score: 86
# Scores: (min: 11, avg: 133.21, max: 376)
#
# Run: 158, exploration: 0.01, score: 41
# Scores: (min: 11, avg: 131.32, max: 376)
#
# Run: 159, exploration: 0.01, score: 212
# Scores: (min: 11, avg: 132.94, max: 376)
#
# Run: 160, exploration: 0.01, score: 128
# Scores: (min: 11, avg: 132.43, max: 376)
#
# Run: 161, exploration: 0.01, score: 282
# Scores: (min: 11, avg: 133.44, max: 376)
#
# Run: 162, exploration: 0.01, score: 43
# Scores: (min: 11, avg: 133.38, max: 376)
#
# Run: 163, exploration: 0.01, score: 85
# Scores: (min: 11, avg: 131.69, max: 376)
#
# Run: 164, exploration: 0.01, score: 218
# Scores: (min: 11, avg: 133.56, max: 376)
#
# Run: 165, exploration: 0.01, score: 124
# Scores: (min: 11, avg: 132.55, max: 376)
#
# Run: 166, exploration: 0.01, score: 215
# Scores: (min: 11, avg: 133.95, max: 376)
#
# Run: 167, exploration: 0.01, score: 40
# Scores: (min: 11, avg: 132.77, max: 376)
#
# Run: 168, exploration: 0.01, score: 196
# Scores: (min: 11, avg: 133.59, max: 376)
#
# Run: 169, exploration: 0.01, score: 252
# Scores: (min: 11, avg: 133.82, max: 376)
#
# Run: 170, exploration: 0.01, score: 134
# Scores: (min: 11, avg: 132.74, max: 376)
#
# Run: 171, exploration: 0.01, score: 86
# Scores: (min: 11, avg: 131.23, max: 376)
#
# Run: 172, exploration: 0.01, score: 91
# Scores: (min: 11, avg: 131.22, max: 376)
#
# Run: 173, exploration: 0.01, score: 73
# Scores: (min: 11, avg: 131.43, max: 376)
#
# Run: 174, exploration: 0.01, score: 289
# Scores: (min: 11, avg: 132.41, max: 376)
#
# Run: 175, exploration: 0.01, score: 228
# Scores: (min: 11, avg: 133.8, max: 376)
#
# Run: 176, exploration: 0.01, score: 178
# Scores: (min: 11, avg: 134.17, max: 376)
#
# Run: 177, exploration: 0.01, score: 226
# Scores: (min: 11, avg: 133.96, max: 376)
#
# Run: 178, exploration: 0.01, score: 157
# Scores: (min: 11, avg: 134.32, max: 376)
#
# Run: 179, exploration: 0.01, score: 149
# Scores: (min: 11, avg: 133.9, max: 376)
#
# Run: 180, exploration: 0.01, score: 141
# Scores: (min: 11, avg: 133.58, max: 376)
#
# Run: 181, exploration: 0.01, score: 94
# Scores: (min: 11, avg: 132.16, max: 376)
#
# Run: 182, exploration: 0.01, score: 81
# Scores: (min: 11, avg: 131.93, max: 376)
#
# Run: 183, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 130.63, max: 376)
#
# Run: 184, exploration: 0.01, score: 32
# Scores: (min: 11, avg: 129.23, max: 376)
#
# Run: 185, exploration: 0.01, score: 90
# Scores: (min: 11, avg: 129.18, max: 376)
#
# Run: 186, exploration: 0.01, score: 104
# Scores: (min: 11, avg: 128.09, max: 376)
#
# Run: 187, exploration: 0.01, score: 269
# Scores: (min: 11, avg: 130.28, max: 376)
#
# Run: 188, exploration: 0.01, score: 131
# Scores: (min: 11, avg: 127.96, max: 376)
#
# Run: 189, exploration: 0.01, score: 32
# Scores: (min: 11, avg: 127.07, max: 376)
#
# Run: 190, exploration: 0.01, score: 31
# Scores: (min: 11, avg: 124.61, max: 376)
#
# Run: 191, exploration: 0.01, score: 69
# Scores: (min: 11, avg: 121.54, max: 369)
#
# Run: 192, exploration: 0.01, score: 31
# Scores: (min: 11, avg: 121.3, max: 369)
#
# Run: 193, exploration: 0.01, score: 126
# Scores: (min: 11, avg: 122.27, max: 369)
#
# Run: 194, exploration: 0.01, score: 111
# Scores: (min: 11, avg: 122.11, max: 369)
#
# Run: 195, exploration: 0.01, score: 136
# Scores: (min: 11, avg: 122.34, max: 369)
#
# Run: 196, exploration: 0.01, score: 37
# Scores: (min: 11, avg: 119.35, max: 369)
#
# Run: 197, exploration: 0.01, score: 184
# Scores: (min: 11, avg: 120.15, max: 369)
#
# Run: 198, exploration: 0.01, score: 162
# Scores: (min: 11, avg: 120.79, max: 369)
#
# Run: 199, exploration: 0.01, score: 54
# Scores: (min: 11, avg: 120.65, max: 369)
#
# Run: 200, exploration: 0.01, score: 190
# Scores: (min: 11, avg: 122.19, max: 369)
#
# Run: 201, exploration: 0.01, score: 160
# Scores: (min: 11, avg: 123.19, max: 369)
#
# Run: 202, exploration: 0.01, score: 40
# Scores: (min: 11, avg: 122.05, max: 369)
#
# Run: 203, exploration: 0.01, score: 137
# Scores: (min: 11, avg: 121.75, max: 369)
#
# Run: 204, exploration: 0.01, score: 232
# Scores: (min: 11, avg: 123.21, max: 369)
#
# Run: 205, exploration: 0.01, score: 104
# Scores: (min: 11, avg: 121.15, max: 369)
#
# Run: 206, exploration: 0.01, score: 92
# Scores: (min: 11, avg: 120.37, max: 369)
#
# Run: 207, exploration: 0.01, score: 170
# Scores: (min: 11, avg: 119.8, max: 369)
#
# Run: 208, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 119.12, max: 369)
#
# Run: 209, exploration: 0.01, score: 101
# Scores: (min: 11, avg: 119.9, max: 369)
#
# Run: 210, exploration: 0.01, score: 155
# Scores: (min: 11, avg: 120.98, max: 369)
#
# Run: 211, exploration: 0.01, score: 30
# Scores: (min: 11, avg: 119.73, max: 369)
#
# Run: 212, exploration: 0.01, score: 83
# Scores: (min: 11, avg: 120.21, max: 369)
#
# Run: 213, exploration: 0.01, score: 179
# Scores: (min: 11, avg: 119.15, max: 369)
#
# Run: 214, exploration: 0.01, score: 184
# Scores: (min: 11, avg: 120.12, max: 369)
#
# Run: 215, exploration: 0.01, score: 261
# Scores: (min: 11, avg: 122.14, max: 369)
#
# Run: 216, exploration: 0.01, score: 115
# Scores: (min: 11, avg: 121.48, max: 369)
#
# Run: 217, exploration: 0.01, score: 19
# Scores: (min: 11, avg: 120.41, max: 369)
#
# Run: 218, exploration: 0.01, score: 49
# Scores: (min: 11, avg: 120.37, max: 369)
#
# Run: 219, exploration: 0.01, score: 124
# Scores: (min: 11, avg: 121.06, max: 369)
#
# Run: 220, exploration: 0.01, score: 101
# Scores: (min: 11, avg: 121.57, max: 369)
#
# Run: 221, exploration: 0.01, score: 82
# Scores: (min: 11, avg: 121.68, max: 369)
#
# Run: 222, exploration: 0.01, score: 155
# Scores: (min: 11, avg: 122.12, max: 369)
#
# Run: 223, exploration: 0.01, score: 209
# Scores: (min: 11, avg: 120.72, max: 369)
#
# Run: 224, exploration: 0.01, score: 154
# Scores: (min: 11, avg: 121.03, max: 369)
#
# Run: 225, exploration: 0.01, score: 27
# Scores: (min: 11, avg: 118.94, max: 369)
#
# Run: 226, exploration: 0.01, score: 114
# Scores: (min: 11, avg: 118.8, max: 369)
#
# Run: 227, exploration: 0.01, score: 37
# Scores: (min: 11, avg: 118.52, max: 369)
#
# Run: 228, exploration: 0.01, score: 113
# Scores: (min: 11, avg: 118.39, max: 369)
#
# Run: 229, exploration: 0.01, score: 21
# Scores: (min: 11, avg: 118.13, max: 369)
#
# Run: 230, exploration: 0.01, score: 95
# Scores: (min: 11, avg: 118.09, max: 369)
#
# Run: 231, exploration: 0.01, score: 18
# Scores: (min: 11, avg: 116.48, max: 369)
#
# Run: 232, exploration: 0.01, score: 27
# Scores: (min: 11, avg: 115.64, max: 369)
#
# Run: 233, exploration: 0.01, score: 209
# Scores: (min: 11, avg: 116.49, max: 369)
#
# Run: 234, exploration: 0.01, score: 93
# Scores: (min: 11, avg: 114.52, max: 369)
#
# Run: 235, exploration: 0.01, score: 96
# Scores: (min: 11, avg: 115.14, max: 369)
#
# Run: 236, exploration: 0.01, score: 75
# Scores: (min: 11, avg: 115.25, max: 369)
#
# Run: 237, exploration: 0.01, score: 132
# Scores: (min: 11, avg: 116.03, max: 369)
#
# Run: 238, exploration: 0.01, score: 52
# Scores: (min: 11, avg: 116.04, max: 369)
#
# Run: 239, exploration: 0.01, score: 222
# Scores: (min: 11, avg: 117.64, max: 369)
#
# Run: 240, exploration: 0.01, score: 74
# Scores: (min: 11, avg: 117.85, max: 369)
#
# Run: 241, exploration: 0.01, score: 117
# Scores: (min: 11, avg: 117.51, max: 369)
#
# Run: 242, exploration: 0.01, score: 118
# Scores: (min: 11, avg: 117.74, max: 369)
#
# Run: 243, exploration: 0.01, score: 37
# Scores: (min: 11, avg: 115.98, max: 369)
#
# Run: 244, exploration: 0.01, score: 46
# Scores: (min: 12, avg: 116.33, max: 369)
#
# Run: 245, exploration: 0.01, score: 46
# Scores: (min: 12, avg: 116.47, max: 369)
#
# Run: 246, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 116.22, max: 369)
#
# Run: 247, exploration: 0.01, score: 15
# Scores: (min: 12, avg: 115.51, max: 369)
#
# Run: 248, exploration: 0.01, score: 36
# Scores: (min: 12, avg: 115.74, max: 369)
#
# Run: 249, exploration: 0.01, score: 112
# Scores: (min: 12, avg: 115.3, max: 369)
#
# Run: 250, exploration: 0.01, score: 87
# Scores: (min: 12, avg: 115.65, max: 369)
#
# Run: 251, exploration: 0.01, score: 62
# Scores: (min: 12, avg: 115.48, max: 369)
#
# Run: 252, exploration: 0.01, score: 33
# Scores: (min: 12, avg: 114.79, max: 369)
#
# Run: 253, exploration: 0.01, score: 367
# Scores: (min: 12, avg: 114.77, max: 367)
#
# Run: 254, exploration: 0.01, score: 28
# Scores: (min: 12, avg: 114.73, max: 367)
#
# Run: 255, exploration: 0.01, score: 21
# Scores: (min: 12, avg: 113.71, max: 367)
#
# Run: 256, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 112.85, max: 367)
#
# Run: 257, exploration: 0.01, score: 144
# Scores: (min: 12, avg: 113.43, max: 367)
#
# Run: 258, exploration: 0.01, score: 61
# Scores: (min: 12, avg: 113.63, max: 367)
#
# Run: 259, exploration: 0.01, score: 146
# Scores: (min: 12, avg: 112.97, max: 367)
#
# Run: 260, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 112.99, max: 367)
#
# Run: 261, exploration: 0.01, score: 46
# Scores: (min: 12, avg: 110.63, max: 367)
#
# Run: 262, exploration: 0.01, score: 221
# Scores: (min: 12, avg: 112.41, max: 367)
#
# Run: 263, exploration: 0.01, score: 28
# Scores: (min: 12, avg: 111.84, max: 367)
#
# Run: 264, exploration: 0.01, score: 117
# Scores: (min: 12, avg: 110.83, max: 367)
#
# Run: 265, exploration: 0.01, score: 53
# Scores: (min: 12, avg: 110.12, max: 367)
#
# Run: 266, exploration: 0.01, score: 56
# Scores: (min: 12, avg: 108.53, max: 367)
#
# Run: 267, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 108.23, max: 367)
#
# Run: 268, exploration: 0.01, score: 53
# Scores: (min: 10, avg: 106.8, max: 367)
#
# Run: 269, exploration: 0.01, score: 118
# Scores: (min: 10, avg: 105.46, max: 367)
#
# Run: 270, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 104.27, max: 367)
#
# Run: 271, exploration: 0.01, score: 40
# Scores: (min: 10, avg: 103.81, max: 367)
#
# Run: 272, exploration: 0.01, score: 43
# Scores: (min: 10, avg: 103.33, max: 367)
#
# Run: 273, exploration: 0.01, score: 202
# Scores: (min: 10, avg: 104.62, max: 367)
#
# Run: 274, exploration: 0.01, score: 28
# Scores: (min: 10, avg: 102.01, max: 367)
#
# Run: 275, exploration: 0.01, score: 128
# Scores: (min: 10, avg: 101.01, max: 367)
#
# Run: 276, exploration: 0.01, score: 91
# Scores: (min: 10, avg: 100.14, max: 367)
#
# Run: 277, exploration: 0.01, score: 69
# Scores: (min: 10, avg: 98.57, max: 367)
#
# Run: 278, exploration: 0.01, score: 67
# Scores: (min: 10, avg: 97.67, max: 367)
#
# Run: 279, exploration: 0.01, score: 144
# Scores: (min: 10, avg: 97.62, max: 367)
#
# Run: 280, exploration: 0.01, score: 73
# Scores: (min: 10, avg: 96.94, max: 367)
#
# Run: 281, exploration: 0.01, score: 66
# Scores: (min: 10, avg: 96.66, max: 367)
#
# Run: 282, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 95.96, max: 367)
#
# Run: 283, exploration: 0.01, score: 77
# Scores: (min: 10, avg: 95.28, max: 367)
#
# Run: 284, exploration: 0.01, score: 26
# Scores: (min: 10, avg: 95.22, max: 367)
#
# Run: 285, exploration: 0.01, score: 85
# Scores: (min: 10, avg: 95.17, max: 367)
#
# Run: 286, exploration: 0.01, score: 219
# Scores: (min: 10, avg: 96.32, max: 367)
#
# Run: 287, exploration: 0.01, score: 63
# Scores: (min: 10, avg: 94.26, max: 367)
#
# Run: 288, exploration: 0.01, score: 36
# Scores: (min: 10, avg: 93.31, max: 367)
#
# Run: 289, exploration: 0.01, score: 100
# Scores: (min: 10, avg: 93.99, max: 367)
#
# Run: 290, exploration: 0.01, score: 76
# Scores: (min: 10, avg: 94.44, max: 367)
#
# Run: 291, exploration: 0.01, score: 53
# Scores: (min: 10, avg: 94.28, max: 367)
#
# Run: 292, exploration: 0.01, score: 89
# Scores: (min: 10, avg: 94.86, max: 367)
#
# Run: 293, exploration: 0.01, score: 183
# Scores: (min: 10, avg: 95.43, max: 367)
#
# Run: 294, exploration: 0.01, score: 44
# Scores: (min: 10, avg: 94.76, max: 367)
#
# Run: 295, exploration: 0.01, score: 37
# Scores: (min: 10, avg: 93.77, max: 367)
#
# Run: 296, exploration: 0.01, score: 88
# Scores: (min: 10, avg: 94.28, max: 367)
#
# Run: 297, exploration: 0.01, score: 51
# Scores: (min: 10, avg: 92.95, max: 367)
#
# Run: 298, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 91.44, max: 367)
#
# Run: 299, exploration: 0.01, score: 79
# Scores: (min: 10, avg: 91.69, max: 367)
#
# Run: 300, exploration: 0.01, score: 51
# Scores: (min: 10, avg: 90.3, max: 367)
#
# Run: 301, exploration: 0.01, score: 19
# Scores: (min: 10, avg: 88.89, max: 367)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1e666d067622> in <module>
#       1 # changed discount factor from 0.95 to 0.5
# ----> 2 cartpole()
#
# <ipython-input-5-6115a8d9a8ce> in cartpole()
#      85                 score_logger.add_score(step, run)
#      86                 break
# ---> 87             dqn_solver.experience_replay()
#
# <ipython-input-5-6115a8d9a8ce> in experience_replay(self)
#      55             q_values = self.model.predict(state)
#      56             q_values[0][action] = q_update
# ---> 57             self.model.fit(state, q_values, verbose=0)
#      58         self.exploration_rate *= EXPLORATION_DECAY
#      59         self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)
#
# c:\Users\prest\Desktop\College_Programing\CS-370-Current_Emerging_Trends_in_CS\venv\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# c:\Users\prest\Desktop\College_Programing\CS-370-Current_Emerging_Trends_in_CS\venv\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# c:\Users\prest\Desktop\College_Programing\CS-370-Current_Emerging_Trends_in_CS\venv\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# c:\Users\prest\Desktop\College_Programing\CS-370-Current_Emerging_Trends_in_CS\venv\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# c:\Users\prest\Desktop\College_Programing\CS-370-Current_Emerging_Trends_in_CS\venv\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# c:\Users\prest\Desktop\College_Programing\CS-370-Current_Emerging_Trends_in_CS\venv\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# c:\Users\prest\Desktop\College_Programing\CS-370-Current_Emerging_Trends_in_CS\venv\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# c:\Users\prest\Desktop\College_Programing\CS-370-Current_Emerging_Trends_in_CS\venv\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# I stopped this run after ~2.5 hours when I noticed that the average score had regressed from the 130s when I had checked it last to the 90s and then 88.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  

from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"
  
GAMMA = 0.95
LEARNING_RATE = 0.001
  
MEMORY_SIZE = 1000000
BATCH_SIZE = 20
  
EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.01
EXPLORATION_DECAY = 0.5     # changed exploration decay from 0.995 to 0.5
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
# changed exploration decay from 0.995 to 0.5
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 15
# Scores: (min: 15, avg: 15, max: 15)
#
# Run: 2, exploration: 0.015625, score: 11
# Scores: (min: 11, avg: 13, max: 15)
#
# Run: 3, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 12, max: 15)
#
# Run: 4, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 11.5, max: 15)
#
# Run: 5, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 11.2, max: 15)
#
# Run: 6, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 11, max: 15)
#
# Run: 7, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 10.857142857142858, max: 15)
#
# Run: 8, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 10.875, max: 15)
#
# Run: 9, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 10.777777777777779, max: 15)
#
# Run: 10, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 10.9, max: 15)
#
# Run: 11, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 11.181818181818182, max: 15)
#
# Run: 12, exploration: 0.01, score: 36
# Scores: (min: 10, avg: 13.25, max: 36)
#
# Run: 13, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 12.923076923076923, max: 36)
#
# Run: 14, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 12.714285714285714, max: 36)
#
# Run: 15, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 12.466666666666667, max: 36)
#
# Run: 16, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 12.3125, max: 36)
#
# Run: 17, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 12.176470588235293, max: 36)
#
# Run: 18, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 12.11111111111111, max: 36)
#
# Run: 19, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 11.947368421052632, max: 36)
#
# Run: 20, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 11.8, max: 36)
#
# Run: 21, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 11.714285714285714, max: 36)
#
# Run: 22, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 11.636363636363637, max: 36)
#
# Run: 23, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 11.565217391304348, max: 36)
#
# Run: 24, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.416666666666666, max: 36)
#
# Run: 25, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.4, max: 36)
#
# Run: 26, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.26923076923077, max: 36)
#
# Run: 27, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.25925925925926, max: 36)
#
# Run: 28, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.214285714285714, max: 36)
#
# Run: 29, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.172413793103448, max: 36)
#
# Run: 30, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.133333333333333, max: 36)
#
# Run: 31, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.064516129032258, max: 36)
#
# Run: 32, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11, max: 36)
#
# Run: 33, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.030303030303031, max: 36)
#
# Run: 34, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.941176470588236, max: 36)
#
# Run: 35, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.971428571428572, max: 36)
#
# Run: 36, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11, max: 36)
#
# Run: 37, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11, max: 36)
#
# Run: 38, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.078947368421053, max: 36)
#
# Run: 39, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 11.256410256410257, max: 36)
#
# Run: 40, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 11.5, max: 36)
#
# Run: 41, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.585365853658537, max: 36)
#
# Run: 42, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 12.19047619047619, max: 37)
#
# Run: 43, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.279069767441861, max: 37)
#
# Run: 44, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 13.204545454545455, max: 53)
#
# Run: 45, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 13.955555555555556, max: 53)
#
# Run: 46, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 14.130434782608695, max: 53)
#
# Run: 47, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 14.425531914893616, max: 53)
#
# Run: 48, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 15.625, max: 72)
#
# Run: 49, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 16.408163265306122, max: 72)
#
# Run: 50, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 16.58, max: 72)
#
# Run: 51, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 16.80392156862745, max: 72)
#
# Run: 52, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 17.057692307692307, max: 72)
#
# Run: 53, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 18.245283018867923, max: 80)
#
# Run: 54, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 18.72222222222222, max: 80)
#
# Run: 55, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 19.163636363636364, max: 80)
#
# Run: 56, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 19.660714285714285, max: 80)
#
# Run: 57, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 19.789473684210527, max: 80)
#
# Run: 58, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 20.53448275862069, max: 80)
#
# Run: 59, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 21.406779661016948, max: 80)
#
# Run: 60, exploration: 0.01, score: 77
# Scores: (min: 8, avg: 22.333333333333332, max: 80)
#
# Run: 61, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 23.59016393442623, max: 99)
#
# Run: 62, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 24.774193548387096, max: 99)
#
# Run: 63, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 26.26984126984127, max: 119)
#
# Run: 64, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 27.15625, max: 119)
#
# Run: 65, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 28.523076923076925, max: 119)
#
# Run: 66, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 29.348484848484848, max: 119)
#
# Run: 67, exploration: 0.01, score: 103
# Scores: (min: 8, avg: 30.44776119402985, max: 119)
#
# Run: 68, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 31.073529411764707, max: 119)
#
# Run: 69, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 32.20289855072464, max: 119)
#
# Run: 70, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 32.8, max: 119)
#
# Run: 71, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 33.67605633802817, max: 119)
#
# Run: 72, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 34.52777777777778, max: 119)
#
# Run: 73, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 35.082191780821915, max: 119)
#
# Run: 74, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 35.83783783783784, max: 119)
#
# Run: 75, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 36.78666666666667, max: 119)
#
# Run: 76, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 37.5, max: 119)
#
# Run: 77, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 38.54545454545455, max: 119)
#
# Run: 78, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 39.57692307692308, max: 119)
#
# Run: 79, exploration: 0.01, score: 115
# Scores: (min: 8, avg: 40.53164556962025, max: 119)
#
# Run: 80, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 41.275, max: 119)
#
# Run: 81, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 41.80246913580247, max: 119)
#
# Run: 82, exploration: 0.01, score: 102
# Scores: (min: 8, avg: 42.53658536585366, max: 119)
#
# Run: 83, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 43.10843373493976, max: 119)
#
# Run: 84, exploration: 0.01, score: 96
# Scores: (min: 8, avg: 43.73809523809524, max: 119)
#
# Run: 85, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 45.15294117647059, max: 164)
#
# Run: 86, exploration: 0.01, score: 101
# Scores: (min: 8, avg: 45.80232558139535, max: 164)
#
# Run: 87, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 46.49425287356322, max: 164)
#
# Run: 88, exploration: 0.01, score: 112
# Scores: (min: 8, avg: 47.23863636363637, max: 164)
#
# Run: 89, exploration: 0.01, score: 110
# Scores: (min: 8, avg: 47.943820224719104, max: 164)
#
# Run: 90, exploration: 0.01, score: 101
# Scores: (min: 8, avg: 48.53333333333333, max: 164)
#
# Run: 91, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 49.68131868131868, max: 164)
#
# Run: 92, exploration: 0.01, score: 101
# Scores: (min: 8, avg: 50.23913043478261, max: 164)
#
# Run: 93, exploration: 0.01, score: 110
# Scores: (min: 8, avg: 50.88172043010753, max: 164)
#
# Run: 94, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 51.340425531914896, max: 164)
#
# Run: 95, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 52.03157894736842, max: 164)
#
# Run: 96, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 52.90625, max: 164)
#
# Run: 97, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 53.7319587628866, max: 164)
#
# Run: 98, exploration: 0.01, score: 211
# Scores: (min: 8, avg: 55.33673469387755, max: 211)
#
# Run: 99, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 56.18181818181818, max: 211)
#
# Run: 100, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 56.71, max: 211)
#
# Run: 101, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 57.76, max: 211)
#
# Run: 102, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 58.56, max: 211)
#
# Run: 103, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 59.62, max: 211)
#
# Run: 104, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 60.47, max: 211)
#
# Run: 105, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 61.46, max: 211)
#
# Run: 106, exploration: 0.01, score: 121
# Scores: (min: 8, avg: 62.57, max: 211)
#
# Run: 107, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 63.75, max: 211)
#
# Run: 108, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 65.02, max: 211)
#
# Run: 109, exploration: 0.01, score: 129
# Scores: (min: 8, avg: 66.21, max: 211)
#
# Run: 110, exploration: 0.01, score: 112
# Scores: (min: 8, avg: 67.21, max: 211)
#
# Run: 111, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 68.25, max: 211)
#
# Run: 112, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 69.12, max: 211)
#
# Run: 113, exploration: 0.01, score: 135
# Scores: (min: 8, avg: 70.38, max: 211)
#
# Run: 114, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 71.79, max: 211)
#
# Run: 115, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 73.23, max: 211)
#
# Run: 116, exploration: 0.01, score: 148
# Scores: (min: 8, avg: 74.61, max: 211)
#
# Run: 117, exploration: 0.01, score: 229
# Scores: (min: 8, avg: 76.8, max: 229)
#
# Run: 118, exploration: 0.01, score: 148
# Scores: (min: 8, avg: 78.17, max: 229)
#
# Run: 119, exploration: 0.01, score: 193
# Scores: (min: 8, avg: 80.01, max: 229)
#
# Run: 120, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 81.43, max: 229)
#
# Run: 121, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 83.13, max: 229)
#
# Run: 122, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 84.31, max: 229)
#
# Run: 123, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 85.54, max: 229)
#
# Run: 124, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 86.88, max: 229)
#
# Run: 125, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 88.19, max: 229)
#
# Run: 126, exploration: 0.01, score: 148
# Scores: (min: 8, avg: 89.59, max: 229)
#
# Run: 127, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 90.9, max: 229)
#
# Run: 128, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 92.23, max: 229)
#
# Run: 129, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 93.39, max: 229)
#
# Run: 130, exploration: 0.01, score: 131
# Scores: (min: 8, avg: 94.6, max: 229)
#
# Run: 131, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 95.87, max: 229)
#
# Run: 132, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 97.1, max: 229)
#
# Run: 133, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 98.49, max: 229)
#
# Run: 134, exploration: 0.01, score: 148
# Scores: (min: 11, avg: 99.89, max: 229)
#
# Run: 135, exploration: 0.01, score: 128
# Scores: (min: 11, avg: 101.05, max: 229)
#
# Run: 136, exploration: 0.01, score: 120
# Scores: (min: 11, avg: 102.13, max: 229)
#
# Run: 137, exploration: 0.01, score: 140
# Scores: (min: 14, avg: 103.42, max: 229)
#
# Run: 138, exploration: 0.01, score: 138
# Scores: (min: 15, avg: 104.66, max: 229)
#
# Run: 139, exploration: 0.01, score: 161
# Scores: (min: 15, avg: 106.09, max: 229)
#
# Run: 140, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 106, max: 229)
#
# Run: 141, exploration: 0.01, score: 107
# Scores: (min: 12, avg: 106.92, max: 229)
#
# Run: 142, exploration: 0.01, score: 136
# Scores: (min: 12, avg: 107.91, max: 229)
#
# Run: 143, exploration: 0.01, score: 135
# Scores: (min: 12, avg: 109.1, max: 229)
#
# Run: 144, exploration: 0.01, score: 114
# Scores: (min: 12, avg: 109.71, max: 229)
#
# Run: 145, exploration: 0.01, score: 221
# Scores: (min: 12, avg: 111.45, max: 229)
#
# Run: 146, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 112.34, max: 229)
#
# Run: 147, exploration: 0.01, score: 110
# Scores: (min: 12, avg: 113.16, max: 229)
#
# Run: 148, exploration: 0.01, score: 126
# Scores: (min: 12, avg: 113.7, max: 229)
#
# Run: 149, exploration: 0.01, score: 164
# Scores: (min: 12, avg: 114.8, max: 229)
#
# Run: 150, exploration: 0.01, score: 105
# Scores: (min: 12, avg: 115.6, max: 229)
#
# Run: 151, exploration: 0.01, score: 352
# Scores: (min: 12, avg: 118.84, max: 352)
#
# Run: 152, exploration: 0.01, score: 122
# Scores: (min: 12, avg: 119.76, max: 352)
#
# Run: 153, exploration: 0.01, score: 168
# Scores: (min: 12, avg: 120.64, max: 352)
#
# Run: 154, exploration: 0.01, score: 139
# Scores: (min: 12, avg: 121.59, max: 352)
#
# Run: 155, exploration: 0.01, score: 162
# Scores: (min: 12, avg: 122.78, max: 352)
#
# Run: 156, exploration: 0.01, score: 184
# Scores: (min: 12, avg: 124.15, max: 352)
#
# Run: 157, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 125.18, max: 352)
#
# Run: 158, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 124.67, max: 352)
#
# Run: 159, exploration: 0.01, score: 114
# Scores: (min: 12, avg: 125.09, max: 352)
#
# Run: 160, exploration: 0.01, score: 105
# Scores: (min: 12, avg: 125.37, max: 352)
#
# Run: 161, exploration: 0.01, score: 140
# Scores: (min: 12, avg: 125.78, max: 352)
#
# Run: 162, exploration: 0.01, score: 25
# Scores: (min: 12, avg: 125.06, max: 352)
#
# Run: 163, exploration: 0.01, score: 84
# Scores: (min: 12, avg: 124.71, max: 352)
#
# Run: 164, exploration: 0.01, score: 140
# Scores: (min: 12, avg: 125.28, max: 352)
#
# Run: 165, exploration: 0.01, score: 167
# Scores: (min: 12, avg: 125.79, max: 352)
#
# Run: 166, exploration: 0.01, score: 151
# Scores: (min: 12, avg: 126.47, max: 352)
#
# Run: 167, exploration: 0.01, score: 102
# Scores: (min: 12, avg: 126.46, max: 352)
#
# Run: 168, exploration: 0.01, score: 199
# Scores: (min: 12, avg: 127.72, max: 352)
#
# Run: 169, exploration: 0.01, score: 87
# Scores: (min: 12, avg: 127.5, max: 352)
#
# Run: 170, exploration: 0.01, score: 189
# Scores: (min: 12, avg: 128.65, max: 352)
#
# Run: 171, exploration: 0.01, score: 109
# Scores: (min: 12, avg: 128.79, max: 352)
#
# Run: 172, exploration: 0.01, score: 143
# Scores: (min: 12, avg: 129.27, max: 352)
#
# Run: 173, exploration: 0.01, score: 256
# Scores: (min: 12, avg: 131.08, max: 352)
#
# Run: 174, exploration: 0.01, score: 158
# Scores: (min: 12, avg: 131.75, max: 352)
#
# Run: 175, exploration: 0.01, score: 139
# Scores: (min: 12, avg: 132.07, max: 352)
#
# Run: 176, exploration: 0.01, score: 169
# Scores: (min: 12, avg: 132.85, max: 352)
#
# Run: 177, exploration: 0.01, score: 349
# Scores: (min: 12, avg: 135.16, max: 352)
#
# Run: 178, exploration: 0.01, score: 25
# Scores: (min: 12, avg: 134.22, max: 352)
#
# Run: 179, exploration: 0.01, score: 136
# Scores: (min: 12, avg: 134.43, max: 352)
#
# Run: 180, exploration: 0.01, score: 170
# Scores: (min: 12, avg: 135.13, max: 352)
#
# Run: 181, exploration: 0.01, score: 44
# Scores: (min: 12, avg: 134.73, max: 352)
#
# Run: 182, exploration: 0.01, score: 49
# Scores: (min: 12, avg: 134.2, max: 352)
#
# Run: 183, exploration: 0.01, score: 113
# Scores: (min: 12, avg: 134.43, max: 352)
#
# Run: 184, exploration: 0.01, score: 185
# Scores: (min: 12, avg: 135.32, max: 352)
#
# Run: 185, exploration: 0.01, score: 127
# Scores: (min: 12, avg: 134.95, max: 352)
#
# Run: 186, exploration: 0.01, score: 313
# Scores: (min: 12, avg: 137.07, max: 352)
#
# Run: 187, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 137.12, max: 352)
#
# Run: 188, exploration: 0.01, score: 319
# Scores: (min: 12, avg: 139.19, max: 352)
#
# Run: 189, exploration: 0.01, score: 138
# Scores: (min: 12, avg: 139.47, max: 352)
#
# Run: 190, exploration: 0.01, score: 110
# Scores: (min: 12, avg: 139.56, max: 352)
#
# Run: 191, exploration: 0.01, score: 134
# Scores: (min: 12, avg: 139.37, max: 352)
#
# Run: 192, exploration: 0.01, score: 190
# Scores: (min: 12, avg: 140.26, max: 352)
#
# Run: 193, exploration: 0.01, score: 141
# Scores: (min: 12, avg: 140.57, max: 352)
#
# Run: 194, exploration: 0.01, score: 53
# Scores: (min: 12, avg: 140.16, max: 352)
#
# Run: 195, exploration: 0.01, score: 62
# Scores: (min: 12, avg: 139.61, max: 352)
#
# Run: 196, exploration: 0.01, score: 53
# Scores: (min: 12, avg: 138.78, max: 352)
#
# Run: 197, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 138.56, max: 352)
#
# Run: 198, exploration: 0.01, score: 186
# Scores: (min: 12, avg: 138.31, max: 352)
#
# Run: 199, exploration: 0.01, score: 155
# Scores: (min: 12, avg: 138.47, max: 352)
#
# Run: 200, exploration: 0.01, score: 132
# Scores: (min: 12, avg: 138.7, max: 352)
#
# Run: 201, exploration: 0.01, score: 200
# Scores: (min: 12, avg: 139.5, max: 352)
#
# Run: 202, exploration: 0.01, score: 127
# Scores: (min: 12, avg: 139.86, max: 352)
#
# Run: 203, exploration: 0.01, score: 335
# Scores: (min: 12, avg: 142.05, max: 352)
#
# Run: 204, exploration: 0.01, score: 144
# Scores: (min: 12, avg: 142.54, max: 352)
#
# Run: 205, exploration: 0.01, score: 14
# Scores: (min: 12, avg: 141.59, max: 352)
#
# Run: 206, exploration: 0.01, score: 131
# Scores: (min: 12, avg: 141.69, max: 352)
#
# Run: 207, exploration: 0.01, score: 140
# Scores: (min: 12, avg: 141.81, max: 352)
#
# Run: 208, exploration: 0.01, score: 143
# Scores: (min: 12, avg: 141.86, max: 352)
#
# Run: 209, exploration: 0.01, score: 102
# Scores: (min: 12, avg: 141.59, max: 352)
#
# Run: 210, exploration: 0.01, score: 175
# Scores: (min: 12, avg: 142.22, max: 352)
#
# Run: 211, exploration: 0.01, score: 256
# Scores: (min: 12, avg: 143.6, max: 352)
#
# Run: 212, exploration: 0.01, score: 157
# Scores: (min: 12, avg: 143.94, max: 352)
#
# Run: 213, exploration: 0.01, score: 319
# Scores: (min: 12, avg: 145.78, max: 352)
#
# Run: 214, exploration: 0.01, score: 273
# Scores: (min: 12, avg: 147, max: 352)
#
# Run: 215, exploration: 0.01, score: 170
# Scores: (min: 12, avg: 147.17, max: 352)
#
# Run: 216, exploration: 0.01, score: 16
# Scores: (min: 12, avg: 145.85, max: 352)
#
# Run: 217, exploration: 0.01, score: 18
# Scores: (min: 12, avg: 143.74, max: 352)
#
# Run: 218, exploration: 0.01, score: 206
# Scores: (min: 12, avg: 144.32, max: 352)
#
# Run: 219, exploration: 0.01, score: 169
# Scores: (min: 12, avg: 144.08, max: 352)
#
# Run: 220, exploration: 0.01, score: 132
# Scores: (min: 12, avg: 143.89, max: 352)
#
# Run: 221, exploration: 0.01, score: 133
# Scores: (min: 12, avg: 143.42, max: 352)
#
# Run: 222, exploration: 0.01, score: 96
# Scores: (min: 12, avg: 143.1, max: 352)
#
# Run: 223, exploration: 0.01, score: 368
# Scores: (min: 12, avg: 145.45, max: 368)
#
# Run: 224, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 145.45, max: 368)
#
# Run: 225, exploration: 0.01, score: 18
# Scores: (min: 12, avg: 144.21, max: 368)
#
# Run: 226, exploration: 0.01, score: 69
# Scores: (min: 12, avg: 143.42, max: 368)
#
# Run: 227, exploration: 0.01, score: 153
# Scores: (min: 12, avg: 143.53, max: 368)
#
# Run: 228, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 143.52, max: 368)
#
# Run: 229, exploration: 0.01, score: 113
# Scores: (min: 12, avg: 143.39, max: 368)
#
# Run: 230, exploration: 0.01, score: 160
# Scores: (min: 12, avg: 143.68, max: 368)
#
# Run: 231, exploration: 0.01, score: 119
# Scores: (min: 12, avg: 143.51, max: 368)
#
# Run: 232, exploration: 0.01, score: 185
# Scores: (min: 12, avg: 144.04, max: 368)
#
# Run: 233, exploration: 0.01, score: 175
# Scores: (min: 12, avg: 144.28, max: 368)
#
# Run: 234, exploration: 0.01, score: 121
# Scores: (min: 12, avg: 144.01, max: 368)
#
# Run: 235, exploration: 0.01, score: 47
# Scores: (min: 12, avg: 143.2, max: 368)
#
# Run: 236, exploration: 0.01, score: 117
# Scores: (min: 12, avg: 143.17, max: 368)
#
# Run: 237, exploration: 0.01, score: 49
# Scores: (min: 12, avg: 142.26, max: 368)
#
# Run: 238, exploration: 0.01, score: 99
# Scores: (min: 12, avg: 141.87, max: 368)
#
# Run: 239, exploration: 0.01, score: 108
# Scores: (min: 12, avg: 141.34, max: 368)
#
# Run: 240, exploration: 0.01, score: 89
# Scores: (min: 12, avg: 142.11, max: 368)
#
# Run: 241, exploration: 0.01, score: 109
# Scores: (min: 12, avg: 142.13, max: 368)
#
# Run: 242, exploration: 0.01, score: 165
# Scores: (min: 12, avg: 142.42, max: 368)
#
# Run: 243, exploration: 0.01, score: 126
# Scores: (min: 12, avg: 142.33, max: 368)
#
# Run: 244, exploration: 0.01, score: 152
# Scores: (min: 12, avg: 142.71, max: 368)
#
# Run: 245, exploration: 0.01, score: 106
# Scores: (min: 12, avg: 141.56, max: 368)
#
# Run: 246, exploration: 0.01, score: 14
# Scores: (min: 12, avg: 140.59, max: 368)
#
# Run: 247, exploration: 0.01, score: 119
# Scores: (min: 12, avg: 140.68, max: 368)
#
# Run: 248, exploration: 0.01, score: 143
# Scores: (min: 12, avg: 140.85, max: 368)
#
# Run: 249, exploration: 0.01, score: 76
# Scores: (min: 12, avg: 139.97, max: 368)
#
# Run: 250, exploration: 0.01, score: 79
# Scores: (min: 12, avg: 139.71, max: 368)
#
# Run: 251, exploration: 0.01, score: 146
# Scores: (min: 12, avg: 137.65, max: 368)
#
# Run: 252, exploration: 0.01, score: 132
# Scores: (min: 12, avg: 137.75, max: 368)
#
# Run: 253, exploration: 0.01, score: 165
# Scores: (min: 12, avg: 137.72, max: 368)
#
# Run: 254, exploration: 0.01, score: 190
# Scores: (min: 12, avg: 138.23, max: 368)
#
# Run: 255, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 137.72, max: 368)
#
# Run: 256, exploration: 0.01, score: 175
# Scores: (min: 12, avg: 137.63, max: 368)
#
# Run: 257, exploration: 0.01, score: 118
# Scores: (min: 12, avg: 137.51, max: 368)
#
# Run: 258, exploration: 0.01, score: 94
# Scores: (min: 14, avg: 138.33, max: 368)
#
# Run: 259, exploration: 0.01, score: 149
# Scores: (min: 14, avg: 138.68, max: 368)
#
# Run: 260, exploration: 0.01, score: 172
# Scores: (min: 14, avg: 139.35, max: 368)
#
# Run: 261, exploration: 0.01, score: 126
# Scores: (min: 14, avg: 139.21, max: 368)
#
# Run: 262, exploration: 0.01, score: 123
# Scores: (min: 14, avg: 140.19, max: 368)
#
# Run: 263, exploration: 0.01, score: 103
# Scores: (min: 14, avg: 140.38, max: 368)
#
# Run: 264, exploration: 0.01, score: 250
# Scores: (min: 14, avg: 141.48, max: 368)
#
# Run: 265, exploration: 0.01, score: 114
# Scores: (min: 14, avg: 140.95, max: 368)
#
# Run: 266, exploration: 0.01, score: 71
# Scores: (min: 14, avg: 140.15, max: 368)
#
# Run: 267, exploration: 0.01, score: 137
# Scores: (min: 14, avg: 140.5, max: 368)
#
# Run: 268, exploration: 0.01, score: 153
# Scores: (min: 14, avg: 140.04, max: 368)
#
# Run: 269, exploration: 0.01, score: 221
# Scores: (min: 14, avg: 141.38, max: 368)
#
# Run: 270, exploration: 0.01, score: 174
# Scores: (min: 14, avg: 141.23, max: 368)
#
# Run: 271, exploration: 0.01, score: 240
# Scores: (min: 14, avg: 142.54, max: 368)
#
# Run: 272, exploration: 0.01, score: 187
# Scores: (min: 14, avg: 142.98, max: 368)
#
# Run: 273, exploration: 0.01, score: 116
# Scores: (min: 14, avg: 141.58, max: 368)
#
# Run: 274, exploration: 0.01, score: 172
# Scores: (min: 14, avg: 141.72, max: 368)
#
# Run: 275, exploration: 0.01, score: 169
# Scores: (min: 14, avg: 142.02, max: 368)
#
# Run: 276, exploration: 0.01, score: 40
# Scores: (min: 14, avg: 140.73, max: 368)
#
# Run: 277, exploration: 0.01, score: 378
# Scores: (min: 14, avg: 141.02, max: 378)
#
# Run: 278, exploration: 0.01, score: 123
# Scores: (min: 14, avg: 142, max: 378)
#
# Run: 279, exploration: 0.01, score: 417
# Scores: (min: 14, avg: 144.81, max: 417)
#
# Run: 280, exploration: 0.01, score: 276
# Scores: (min: 14, avg: 145.87, max: 417)
#
# Run: 281, exploration: 0.01, score: 101
# Scores: (min: 14, avg: 146.44, max: 417)
#
# Run: 282, exploration: 0.01, score: 124
# Scores: (min: 14, avg: 147.19, max: 417)
#
# Run: 283, exploration: 0.01, score: 116
# Scores: (min: 14, avg: 147.22, max: 417)
#
# Run: 284, exploration: 0.01, score: 143
# Scores: (min: 14, avg: 146.8, max: 417)
#
# Run: 285, exploration: 0.01, score: 100
# Scores: (min: 14, avg: 146.53, max: 417)
#
# Run: 286, exploration: 0.01, score: 149
# Scores: (min: 14, avg: 144.89, max: 417)
#
# Run: 287, exploration: 0.01, score: 215
# Scores: (min: 14, avg: 145.93, max: 417)
#
# Run: 288, exploration: 0.01, score: 233
# Scores: (min: 14, avg: 145.07, max: 417)
#
# Run: 289, exploration: 0.01, score: 80
# Scores: (min: 14, avg: 144.49, max: 417)
#
# Run: 290, exploration: 0.01, score: 134
# Scores: (min: 14, avg: 144.73, max: 417)
#
# Run: 291, exploration: 0.01, score: 196
# Scores: (min: 14, avg: 145.35, max: 417)
#
# Run: 292, exploration: 0.01, score: 121
# Scores: (min: 14, avg: 144.66, max: 417)
#
# Run: 293, exploration: 0.01, score: 160
# Scores: (min: 14, avg: 144.85, max: 417)
#
# Run: 294, exploration: 0.01, score: 106
# Scores: (min: 14, avg: 145.38, max: 417)
#
# Run: 295, exploration: 0.01, score: 103
# Scores: (min: 14, avg: 145.79, max: 417)
#
# Run: 296, exploration: 0.01, score: 30
# Scores: (min: 14, avg: 145.56, max: 417)
#
# Run: 297, exploration: 0.01, score: 154
# Scores: (min: 14, avg: 145.99, max: 417)
#
# Run: 298, exploration: 0.01, score: 231
# Scores: (min: 14, avg: 146.44, max: 417)
#
# Run: 299, exploration: 0.01, score: 157
# Scores: (min: 14, avg: 146.46, max: 417)
#
# Run: 300, exploration: 0.01, score: 239
# Scores: (min: 14, avg: 147.53, max: 417)
#
# Run: 301, exploration: 0.01, score: 92
# Scores: (min: 14, avg: 146.45, max: 417)
#
# Run: 302, exploration: 0.01, score: 112
# Scores: (min: 14, avg: 146.3, max: 417)
#
# Run: 303, exploration: 0.01, score: 177
# Scores: (min: 14, avg: 144.72, max: 417)
#
# Run: 304, exploration: 0.01, score: 129
# Scores: (min: 14, avg: 144.57, max: 417)
#
# Run: 305, exploration: 0.01, score: 125
# Scores: (min: 14, avg: 145.68, max: 417)
#
# Run: 306, exploration: 0.01, score: 417
# Scores: (min: 14, avg: 148.54, max: 417)
#
# Run: 307, exploration: 0.01, score: 63
# Scores: (min: 14, avg: 147.77, max: 417)
#
# Run: 308, exploration: 0.01, score: 108
# Scores: (min: 14, avg: 147.42, max: 417)
#
# Run: 309, exploration: 0.01, score: 109
# Scores: (min: 14, avg: 147.49, max: 417)
#
# Run: 310, exploration: 0.01, score: 172
# Scores: (min: 14, avg: 147.46, max: 417)
#
# Run: 311, exploration: 0.01, score: 214
# Scores: (min: 14, avg: 147.04, max: 417)
#
# Run: 312, exploration: 0.01, score: 208
# Scores: (min: 14, avg: 147.55, max: 417)
#
# Run: 313, exploration: 0.01, score: 180
# Scores: (min: 14, avg: 146.16, max: 417)
#
# Run: 314, exploration: 0.01, score: 249
# Scores: (min: 14, avg: 145.92, max: 417)
#
# Run: 315, exploration: 0.01, score: 100
# Scores: (min: 14, avg: 145.22, max: 417)
#
# Run: 316, exploration: 0.01, score: 121
# Scores: (min: 14, avg: 146.27, max: 417)
#
# Run: 317, exploration: 0.01, score: 150
# Scores: (min: 14, avg: 147.59, max: 417)
#
# Run: 318, exploration: 0.01, score: 110
# Scores: (min: 14, avg: 146.63, max: 417)
#
# Run: 319, exploration: 0.01, score: 125
# Scores: (min: 14, avg: 146.19, max: 417)
#
# Run: 320, exploration: 0.01, score: 64
# Scores: (min: 14, avg: 145.51, max: 417)
#
# Run: 321, exploration: 0.01, score: 129
# Scores: (min: 14, avg: 145.47, max: 417)
#
# Run: 322, exploration: 0.01, score: 128
# Scores: (min: 14, avg: 145.79, max: 417)
#
# Run: 323, exploration: 0.01, score: 124
# Scores: (min: 14, avg: 143.35, max: 417)
#
# Run: 324, exploration: 0.01, score: 102
# Scores: (min: 14, avg: 142.95, max: 417)
#
# Run: 325, exploration: 0.01, score: 264
# Scores: (min: 14, avg: 145.41, max: 417)
#
# Run: 326, exploration: 0.01, score: 206
# Scores: (min: 14, avg: 146.78, max: 417)
#
# Run: 327, exploration: 0.01, score: 15
# Scores: (min: 14, avg: 145.4, max: 417)
#
# Run: 328, exploration: 0.01, score: 124
# Scores: (min: 14, avg: 145.22, max: 417)
#
# Run: 329, exploration: 0.01, score: 172
# Scores: (min: 14, avg: 145.81, max: 417)
#
# Run: 330, exploration: 0.01, score: 150
# Scores: (min: 14, avg: 145.71, max: 417)
#
# Run: 331, exploration: 0.01, score: 131
# Scores: (min: 14, avg: 145.83, max: 417)
#
# Run: 332, exploration: 0.01, score: 101
# Scores: (min: 14, avg: 144.99, max: 417)
#
# Run: 333, exploration: 0.01, score: 105
# Scores: (min: 14, avg: 144.29, max: 417)
#
# Run: 334, exploration: 0.01, score: 126
# Scores: (min: 14, avg: 144.34, max: 417)
#
# Run: 335, exploration: 0.01, score: 135
# Scores: (min: 14, avg: 145.22, max: 417)
#
# Run: 336, exploration: 0.01, score: 44
# Scores: (min: 14, avg: 144.49, max: 417)
#
# Run: 337, exploration: 0.01, score: 39
# Scores: (min: 14, avg: 144.39, max: 417)
#
# Run: 338, exploration: 0.01, score: 28
# Scores: (min: 14, avg: 143.68, max: 417)
#
# Run: 339, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 142.71, max: 417)
#
# Run: 340, exploration: 0.01, score: 333
# Scores: (min: 11, avg: 145.15, max: 417)
#
# Run: 341, exploration: 0.01, score: 138
# Scores: (min: 11, avg: 145.44, max: 417)
#
# Run: 342, exploration: 0.01, score: 393
# Scores: (min: 11, avg: 147.72, max: 417)
#
# Run: 343, exploration: 0.01, score: 114
# Scores: (min: 11, avg: 147.6, max: 417)
#
# Run: 344, exploration: 0.01, score: 79
# Scores: (min: 11, avg: 146.87, max: 417)
#
# Run: 345, exploration: 0.01, score: 174
# Scores: (min: 11, avg: 147.55, max: 417)
#
# Run: 346, exploration: 0.01, score: 274
# Scores: (min: 11, avg: 150.15, max: 417)
#
# Run: 347, exploration: 0.01, score: 139
# Scores: (min: 11, avg: 150.35, max: 417)
#
# Run: 348, exploration: 0.01, score: 217
# Scores: (min: 11, avg: 151.09, max: 417)
#
# Run: 349, exploration: 0.01, score: 324
# Scores: (min: 11, avg: 153.57, max: 417)
#
# Run: 350, exploration: 0.01, score: 97
# Scores: (min: 11, avg: 153.75, max: 417)
#
# Run: 351, exploration: 0.01, score: 98
# Scores: (min: 11, avg: 153.27, max: 417)
#
# Run: 352, exploration: 0.01, score: 237
# Scores: (min: 11, avg: 154.32, max: 417)
#
# Run: 353, exploration: 0.01, score: 139
# Scores: (min: 11, avg: 154.06, max: 417)
#
# Run: 354, exploration: 0.01, score: 323
# Scores: (min: 11, avg: 155.39, max: 417)
#
# Run: 355, exploration: 0.01, score: 113
# Scores: (min: 11, avg: 155.41, max: 417)
#
# Run: 356, exploration: 0.01, score: 51
# Scores: (min: 11, avg: 154.17, max: 417)
#
# Run: 357, exploration: 0.01, score: 94
# Scores: (min: 11, avg: 153.93, max: 417)
#
# Run: 358, exploration: 0.01, score: 182
# Scores: (min: 11, avg: 154.81, max: 417)
#
# Run: 359, exploration: 0.01, score: 225
# Scores: (min: 11, avg: 155.57, max: 417)
#
# Run: 360, exploration: 0.01, score: 368
# Scores: (min: 11, avg: 157.53, max: 417)
#
# Run: 361, exploration: 0.01, score: 161
# Scores: (min: 11, avg: 157.88, max: 417)
#
# Run: 362, exploration: 0.01, score: 120
# Scores: (min: 11, avg: 157.85, max: 417)
#
# Run: 363, exploration: 0.01, score: 319
# Scores: (min: 11, avg: 160.01, max: 417)
#
# Run: 364, exploration: 0.01, score: 182
# Scores: (min: 11, avg: 159.33, max: 417)
#
# Run: 365, exploration: 0.01, score: 169
# Scores: (min: 11, avg: 159.88, max: 417)
#
# Run: 366, exploration: 0.01, score: 103
# Scores: (min: 11, avg: 160.2, max: 417)
#
# Run: 367, exploration: 0.01, score: 94
# Scores: (min: 11, avg: 159.77, max: 417)
#
# Run: 368, exploration: 0.01, score: 259
# Scores: (min: 11, avg: 160.83, max: 417)
#
# Run: 369, exploration: 0.01, score: 104
# Scores: (min: 11, avg: 159.66, max: 417)
#
# Run: 370, exploration: 0.01, score: 307
# Scores: (min: 11, avg: 160.99, max: 417)
#
# Run: 371, exploration: 0.01, score: 113
# Scores: (min: 11, avg: 159.72, max: 417)
#
# Run: 372, exploration: 0.01, score: 64
# Scores: (min: 11, avg: 158.49, max: 417)
#
# Run: 373, exploration: 0.01, score: 111
# Scores: (min: 11, avg: 158.44, max: 417)
#
# Run: 374, exploration: 0.01, score: 144
# Scores: (min: 11, avg: 158.16, max: 417)
#
# Run: 375, exploration: 0.01, score: 187
# Scores: (min: 11, avg: 158.34, max: 417)
#
# Run: 376, exploration: 0.01, score: 140
# Scores: (min: 11, avg: 159.34, max: 417)
#
# Run: 377, exploration: 0.01, score: 23
# Scores: (min: 11, avg: 155.79, max: 417)
#
# Run: 378, exploration: 0.01, score: 292
# Scores: (min: 11, avg: 157.48, max: 417)
#
# Run: 379, exploration: 0.01, score: 166
# Scores: (min: 11, avg: 154.97, max: 417)
#
# Run: 380, exploration: 0.01, score: 115
# Scores: (min: 11, avg: 153.36, max: 417)
#
# Run: 381, exploration: 0.01, score: 299
# Scores: (min: 11, avg: 155.34, max: 417)
#
# Run: 382, exploration: 0.01, score: 465
# Scores: (min: 11, avg: 158.75, max: 465)
#
# Run: 383, exploration: 0.01, score: 149
# Scores: (min: 11, avg: 159.08, max: 465)
#
# Run: 384, exploration: 0.01, score: 232
# Scores: (min: 11, avg: 159.97, max: 465)
#
# Run: 385, exploration: 0.01, score: 307
# Scores: (min: 11, avg: 162.04, max: 465)
#
# Run: 386, exploration: 0.01, score: 140
# Scores: (min: 11, avg: 161.95, max: 465)
#
# Run: 387, exploration: 0.01, score: 133
# Scores: (min: 11, avg: 161.13, max: 465)
#
# Run: 388, exploration: 0.01, score: 185
# Scores: (min: 11, avg: 160.65, max: 465)
#
# Run: 389, exploration: 0.01, score: 276
# Scores: (min: 11, avg: 162.61, max: 465)
#
# Run: 390, exploration: 0.01, score: 106
# Scores: (min: 11, avg: 162.33, max: 465)
#
# Run: 391, exploration: 0.01, score: 103
# Scores: (min: 11, avg: 161.4, max: 465)
#
# Run: 392, exploration: 0.01, score: 127
# Scores: (min: 11, avg: 161.46, max: 465)
#
# Run: 393, exploration: 0.01, score: 132
# Scores: (min: 11, avg: 161.18, max: 465)
#
# Run: 394, exploration: 0.01, score: 75
# Scores: (min: 11, avg: 160.87, max: 465)
#
# Run: 395, exploration: 0.01, score: 216
# Scores: (min: 11, avg: 162, max: 465)
#
# Run: 396, exploration: 0.01, score: 51
# Scores: (min: 11, avg: 162.21, max: 465)
#
# Run: 397, exploration: 0.01, score: 182
# Scores: (min: 11, avg: 162.49, max: 465)
#
# Run: 398, exploration: 0.01, score: 129
# Scores: (min: 11, avg: 161.47, max: 465)
#
# Run: 399, exploration: 0.01, score: 105
# Scores: (min: 11, avg: 160.95, max: 465)
#
# Run: 400, exploration: 0.01, score: 146
# Scores: (min: 11, avg: 160.02, max: 465)
#
# Run: 401, exploration: 0.01, score: 65
# Scores: (min: 11, avg: 159.75, max: 465)
#
# Run: 402, exploration: 0.01, score: 162
# Scores: (min: 11, avg: 160.25, max: 465)
#
# Run: 403, exploration: 0.01, score: 90
# Scores: (min: 11, avg: 159.38, max: 465)
#
# Run: 404, exploration: 0.01, score: 221
# Scores: (min: 11, avg: 160.3, max: 465)
#
# Run: 405, exploration: 0.01, score: 107
# Scores: (min: 11, avg: 160.12, max: 465)
#
# Run: 406, exploration: 0.01, score: 136
# Scores: (min: 11, avg: 157.31, max: 465)
#
# Run: 407, exploration: 0.01, score: 235
# Scores: (min: 11, avg: 159.03, max: 465)
#
# Run: 408, exploration: 0.01, score: 75
# Scores: (min: 11, avg: 158.7, max: 465)
#
# Run: 409, exploration: 0.01, score: 284
# Scores: (min: 11, avg: 160.45, max: 465)
#
# Run: 410, exploration: 0.01, score: 111
# Scores: (min: 11, avg: 159.84, max: 465)
#
# Run: 411, exploration: 0.01, score: 149
# Scores: (min: 11, avg: 159.19, max: 465)
#
# Run: 412, exploration: 0.01, score: 169
# Scores: (min: 11, avg: 158.8, max: 465)
#
# Run: 413, exploration: 0.01, score: 326
# Scores: (min: 11, avg: 160.26, max: 465)
#
# Run: 414, exploration: 0.01, score: 260
# Scores: (min: 11, avg: 160.37, max: 465)
#
# Run: 415, exploration: 0.01, score: 62
# Scores: (min: 11, avg: 159.99, max: 465)
#
# Run: 416, exploration: 0.01, score: 146
# Scores: (min: 11, avg: 160.24, max: 465)
#
# Run: 417, exploration: 0.01, score: 150
# Scores: (min: 11, avg: 160.24, max: 465)
#
# Run: 418, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 160.59, max: 465)
#
# Run: 419, exploration: 0.01, score: 237
# Scores: (min: 11, avg: 161.71, max: 465)
#
# Run: 420, exploration: 0.01, score: 178
# Scores: (min: 11, avg: 162.85, max: 465)
#
# Run: 421, exploration: 0.01, score: 175
# Scores: (min: 11, avg: 163.31, max: 465)
#
# Run: 422, exploration: 0.01, score: 282
# Scores: (min: 11, avg: 164.85, max: 465)
#
# Run: 423, exploration: 0.01, score: 260
# Scores: (min: 11, avg: 166.21, max: 465)
#
# Run: 424, exploration: 0.01, score: 243
# Scores: (min: 11, avg: 167.62, max: 465)
#
# Run: 425, exploration: 0.01, score: 308
# Scores: (min: 11, avg: 168.06, max: 465)
#
# Run: 426, exploration: 0.01, score: 77
# Scores: (min: 11, avg: 166.77, max: 465)
#
# Run: 427, exploration: 0.01, score: 127
# Scores: (min: 11, avg: 167.89, max: 465)
#
# Run: 428, exploration: 0.01, score: 167
# Scores: (min: 11, avg: 168.32, max: 465)
#
# Run: 429, exploration: 0.01, score: 120
# Scores: (min: 11, avg: 167.8, max: 465)
#
# Run: 430, exploration: 0.01, score: 153
# Scores: (min: 11, avg: 167.83, max: 465)
#
# Run: 431, exploration: 0.01, score: 247
# Scores: (min: 11, avg: 168.99, max: 465)
#
# Run: 432, exploration: 0.01, score: 451
# Scores: (min: 11, avg: 172.49, max: 465)
#
# Run: 433, exploration: 0.01, score: 151
# Scores: (min: 11, avg: 172.95, max: 465)
#
# Run: 434, exploration: 0.01, score: 98
# Scores: (min: 11, avg: 172.67, max: 465)
#
# Run: 435, exploration: 0.01, score: 179
# Scores: (min: 11, avg: 173.11, max: 465)
#
# Run: 436, exploration: 0.01, score: 126
# Scores: (min: 11, avg: 173.93, max: 465)
#
# Run: 437, exploration: 0.01, score: 155
# Scores: (min: 11, avg: 175.09, max: 465)
#
# Run: 438, exploration: 0.01, score: 248
# Scores: (min: 11, avg: 177.29, max: 465)
#
# Run: 439, exploration: 0.01, score: 120
# Scores: (min: 23, avg: 178.38, max: 465)
#
# Run: 440, exploration: 0.01, score: 213
# Scores: (min: 23, avg: 177.18, max: 465)
#
# Run: 441, exploration: 0.01, score: 189
# Scores: (min: 23, avg: 177.69, max: 465)
#
# Run: 442, exploration: 0.01, score: 160
# Scores: (min: 23, avg: 175.36, max: 465)
#
# Run: 443, exploration: 0.01, score: 89
# Scores: (min: 23, avg: 175.11, max: 465)
#
# Run: 444, exploration: 0.01, score: 233
# Scores: (min: 23, avg: 176.65, max: 465)
#
# Run: 445, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 175.02, max: 465)
#
# Run: 446, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 172.39, max: 465)
#
# Run: 447, exploration: 0.01, score: 297
# Scores: (min: 11, avg: 173.97, max: 465)
#
# Run: 448, exploration: 0.01, score: 133
# Scores: (min: 11, avg: 173.13, max: 465)
#
# Run: 449, exploration: 0.01, score: 148
# Scores: (min: 11, avg: 171.37, max: 465)
#
# Run: 450, exploration: 0.01, score: 156
# Scores: (min: 11, avg: 171.96, max: 465)
#
# Run: 451, exploration: 0.01, score: 179
# Scores: (min: 11, avg: 172.77, max: 465)
#
# Run: 452, exploration: 0.01, score: 188
# Scores: (min: 11, avg: 172.28, max: 465)
#
# Run: 453, exploration: 0.01, score: 326
# Scores: (min: 11, avg: 174.15, max: 465)
#
# Run: 454, exploration: 0.01, score: 151
# Scores: (min: 11, avg: 172.43, max: 465)
#
# Run: 455, exploration: 0.01, score: 153
# Scores: (min: 11, avg: 172.83, max: 465)
#
# Run: 456, exploration: 0.01, score: 115
# Scores: (min: 11, avg: 173.47, max: 465)
#
# Run: 457, exploration: 0.01, score: 190
# Scores: (min: 11, avg: 174.43, max: 465)
#
# Run: 458, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 174.06, max: 465)
#
# Run: 459, exploration: 0.01, score: 229
# Scores: (min: 11, avg: 174.1, max: 465)
#
# Run: 460, exploration: 0.01, score: 153
# Scores: (min: 11, avg: 171.95, max: 465)
#
# Run: 461, exploration: 0.01, score: 156
# Scores: (min: 11, avg: 171.9, max: 465)
#
# Run: 462, exploration: 0.01, score: 196
# Scores: (min: 11, avg: 172.66, max: 465)
#
# Run: 463, exploration: 0.01, score: 170
# Scores: (min: 11, avg: 171.17, max: 465)
#
# Run: 464, exploration: 0.01, score: 171
# Scores: (min: 11, avg: 171.06, max: 465)
#
# Run: 465, exploration: 0.01, score: 319
# Scores: (min: 11, avg: 172.56, max: 465)
#
# Run: 466, exploration: 0.01, score: 341
# Scores: (min: 11, avg: 174.94, max: 465)
#
# Run: 467, exploration: 0.01, score: 286
# Scores: (min: 11, avg: 176.86, max: 465)
#
# Run: 468, exploration: 0.01, score: 146
# Scores: (min: 11, avg: 175.73, max: 465)
#
# Run: 469, exploration: 0.01, score: 283
# Scores: (min: 11, avg: 177.52, max: 465)
#
# Run: 470, exploration: 0.01, score: 275
# Scores: (min: 11, avg: 177.2, max: 465)
#
# Run: 471, exploration: 0.01, score: 194
# Scores: (min: 11, avg: 178.01, max: 465)
#
# Run: 472, exploration: 0.01, score: 112
# Scores: (min: 11, avg: 178.49, max: 465)
#
# Run: 473, exploration: 0.01, score: 430
# Scores: (min: 11, avg: 181.68, max: 465)
#
# Run: 474, exploration: 0.01, score: 161
# Scores: (min: 11, avg: 181.85, max: 465)
#
# Run: 475, exploration: 0.01, score: 137
# Scores: (min: 11, avg: 181.35, max: 465)
#
# Run: 476, exploration: 0.01, score: 110
# Scores: (min: 11, avg: 181.05, max: 465)
#
# Run: 477, exploration: 0.01, score: 123
# Scores: (min: 11, avg: 182.05, max: 465)
#
# Run: 478, exploration: 0.01, score: 114
# Scores: (min: 11, avg: 180.27, max: 465)
#
# Run: 479, exploration: 0.01, score: 177
# Scores: (min: 11, avg: 180.38, max: 465)
#
# Run: 480, exploration: 0.01, score: 110
# Scores: (min: 11, avg: 180.33, max: 465)
#
# Run: 481, exploration: 0.01, score: 190
# Scores: (min: 11, avg: 179.24, max: 465)
#
# Run: 482, exploration: 0.01, score: 292
# Scores: (min: 11, avg: 177.51, max: 451)
#
# Run: 483, exploration: 0.01, score: 125
# Scores: (min: 11, avg: 177.27, max: 451)
#
# Run: 484, exploration: 0.01, score: 253
# Scores: (min: 11, avg: 177.48, max: 451)
#
# Run: 485, exploration: 0.01, score: 157
# Scores: (min: 11, avg: 175.98, max: 451)
#
# Run: 486, exploration: 0.01, score: 111
# Scores: (min: 11, avg: 175.69, max: 451)
#
# Run: 487, exploration: 0.01, score: 257
# Scores: (min: 11, avg: 176.93, max: 451)
#
# Run: 488, exploration: 0.01, score: 244
# Scores: (min: 11, avg: 177.52, max: 451)
#
# Run: 489, exploration: 0.01, score: 97
# Scores: (min: 11, avg: 175.73, max: 451)
#
# Run: 490, exploration: 0.01, score: 29
# Scores: (min: 11, avg: 174.96, max: 451)
#
# Run: 491, exploration: 0.01, score: 36
# Scores: (min: 11, avg: 174.29, max: 451)
#
# Run: 492, exploration: 0.01, score: 160
# Scores: (min: 11, avg: 174.62, max: 451)
#
# Run: 493, exploration: 0.01, score: 260
# Scores: (min: 11, avg: 175.9, max: 451)
#
# Run: 494, exploration: 0.01, score: 187
# Scores: (min: 11, avg: 177.02, max: 451)
#
# Run: 495, exploration: 0.01, score: 165
# Scores: (min: 11, avg: 176.51, max: 451)
#
# Run: 496, exploration: 0.01, score: 114
# Scores: (min: 11, avg: 177.14, max: 451)
#
# Run: 497, exploration: 0.01, score: 193
# Scores: (min: 11, avg: 177.25, max: 451)
#
# Run: 498, exploration: 0.01, score: 132
# Scores: (min: 11, avg: 177.28, max: 451)
#
# Run: 499, exploration: 0.01, score: 18
# Scores: (min: 11, avg: 176.41, max: 451)
#
# Run: 500, exploration: 0.01, score: 16
# Scores: (min: 11, avg: 175.11, max: 451)
#
# Run: 501, exploration: 0.01, score: 16
# Scores: (min: 11, avg: 174.62, max: 451)
#
# Run: 502, exploration: 0.01, score: 13
# Scores: (min: 11, avg: 173.13, max: 451)
#
# Run: 503, exploration: 0.01, score: 257
# Scores: (min: 11, avg: 174.8, max: 451)
#
# Run: 504, exploration: 0.01, score: 253
# Scores: (min: 11, avg: 175.12, max: 451)
#
# Run: 505, exploration: 0.01, score: 98
# Scores: (min: 11, avg: 175.03, max: 451)
#
# Run: 506, exploration: 0.01, score: 133
# Scores: (min: 11, avg: 175, max: 451)
#
# Run: 507, exploration: 0.01, score: 137
# Scores: (min: 11, avg: 174.02, max: 451)
#
# Run: 508, exploration: 0.01, score: 98
# Scores: (min: 11, avg: 174.25, max: 451)
#
# Run: 509, exploration: 0.01, score: 79
# Scores: (min: 11, avg: 172.2, max: 451)
#
# Run: 510, exploration: 0.01, score: 251
# Scores: (min: 11, avg: 173.6, max: 451)
#
# Run: 511, exploration: 0.01, score: 41
# Scores: (min: 11, avg: 172.52, max: 451)
#
# Run: 512, exploration: 0.01, score: 113
# Scores: (min: 11, avg: 171.96, max: 451)
#
# Run: 513, exploration: 0.01, score: 95
# Scores: (min: 11, avg: 169.65, max: 451)
#
# Run: 514, exploration: 0.01, score: 113
# Scores: (min: 11, avg: 168.18, max: 451)
#
# Run: 515, exploration: 0.01, score: 125
# Scores: (min: 11, avg: 168.81, max: 451)
#
# Run: 516, exploration: 0.01, score: 318
# Scores: (min: 11, avg: 170.53, max: 451)
#
# Run: 517, exploration: 0.01, score: 132
# Scores: (min: 11, avg: 170.35, max: 451)
#
# Run: 518, exploration: 0.01, score: 156
# Scores: (min: 11, avg: 170.46, max: 451)
#
# Run: 519, exploration: 0.01, score: 320
# Scores: (min: 11, avg: 171.29, max: 451)
#
# Run: 520, exploration: 0.01, score: 56
# Scores: (min: 11, avg: 170.07, max: 451)
#
# Run: 521, exploration: 0.01, score: 217
# Scores: (min: 11, avg: 170.49, max: 451)
#
# Run: 522, exploration: 0.01, score: 170
# Scores: (min: 11, avg: 169.37, max: 451)
#
# Run: 523, exploration: 0.01, score: 235
# Scores: (min: 11, avg: 169.12, max: 451)
#
# Run: 524, exploration: 0.01, score: 104
# Scores: (min: 11, avg: 167.73, max: 451)
#
# Run: 525, exploration: 0.01, score: 121
# Scores: (min: 11, avg: 165.86, max: 451)
#
# Run: 526, exploration: 0.01, score: 127
# Scores: (min: 11, avg: 166.36, max: 451)
#
# Run: 527, exploration: 0.01, score: 16
# Scores: (min: 11, avg: 165.25, max: 451)
#
# Run: 528, exploration: 0.01, score: 18
# Scores: (min: 11, avg: 163.76, max: 451)
#
# Run: 529, exploration: 0.01, score: 13
# Scores: (min: 11, avg: 162.69, max: 451)
#
# Run: 530, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 161.28, max: 451)
#
# Run: 531, exploration: 0.01, score: 15
# Scores: (min: 11, avg: 158.96, max: 451)
#
# Run: 532, exploration: 0.01, score: 477
# Scores: (min: 11, avg: 159.22, max: 477)
#
# Run: 533, exploration: 0.01, score: 161
# Scores: (min: 11, avg: 159.32, max: 477)
#
# Run: 534, exploration: 0.01, score: 192
# Scores: (min: 11, avg: 160.26, max: 477)
#
# Run: 535, exploration: 0.01, score: 303
# Scores: (min: 11, avg: 161.5, max: 477)
#
# Run: 536, exploration: 0.01, score: 54
# Scores: (min: 11, avg: 160.78, max: 477)
#
# Run: 537, exploration: 0.01, score: 444
# Scores: (min: 11, avg: 163.67, max: 477)
#
# Run: 538, exploration: 0.01, score: 148
# Scores: (min: 11, avg: 162.67, max: 477)
#
# Run: 539, exploration: 0.01, score: 223
# Scores: (min: 11, avg: 163.7, max: 477)
#
# Run: 540, exploration: 0.01, score: 107
# Scores: (min: 11, avg: 162.64, max: 477)
#
# Run: 541, exploration: 0.01, score: 231
# Scores: (min: 11, avg: 163.06, max: 477)
#
# Run: 542, exploration: 0.01, score: 130
# Scores: (min: 11, avg: 162.76, max: 477)
#
# Run: 543, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 166.87, max: 500)
#
# Run: 544, exploration: 0.01, score: 114
# Scores: (min: 11, avg: 165.68, max: 500)
#
# Run: 545, exploration: 0.01, score: 206
# Scores: (min: 11, avg: 167.63, max: 500)
#
# Run: 546, exploration: 0.01, score: 136
# Scores: (min: 12, avg: 168.88, max: 500)
#
# Run: 547, exploration: 0.01, score: 363
# Scores: (min: 12, avg: 169.54, max: 500)
#
# Run: 548, exploration: 0.01, score: 247
# Scores: (min: 12, avg: 170.68, max: 500)
#
# Run: 549, exploration: 0.01, score: 64
# Scores: (min: 12, avg: 169.84, max: 500)
#
# Run: 550, exploration: 0.01, score: 174
# Scores: (min: 12, avg: 170.02, max: 500)
#
# Run: 551, exploration: 0.01, score: 183
# Scores: (min: 12, avg: 170.06, max: 500)
#
# Run: 552, exploration: 0.01, score: 238
# Scores: (min: 12, avg: 170.56, max: 500)
#
# Run: 553, exploration: 0.01, score: 200
# Scores: (min: 12, avg: 169.3, max: 500)
#
# Run: 554, exploration: 0.01, score: 200
# Scores: (min: 12, avg: 169.79, max: 500)
#
# Run: 555, exploration: 0.01, score: 145
# Scores: (min: 12, avg: 169.71, max: 500)
#
# Run: 556, exploration: 0.01, score: 442
# Scores: (min: 12, avg: 172.98, max: 500)
#
# Run: 557, exploration: 0.01, score: 166
# Scores: (min: 12, avg: 172.74, max: 500)
#
# Run: 558, exploration: 0.01, score: 227
# Scores: (min: 12, avg: 173.56, max: 500)
#
# Run: 559, exploration: 0.01, score: 156
# Scores: (min: 12, avg: 172.83, max: 500)
#
# Run: 560, exploration: 0.01, score: 213
# Scores: (min: 12, avg: 173.43, max: 500)
#
# Run: 561, exploration: 0.01, score: 152
# Scores: (min: 12, avg: 173.39, max: 500)
#
# Run: 562, exploration: 0.01, score: 114
# Scores: (min: 12, avg: 172.57, max: 500)
#
# Run: 563, exploration: 0.01, score: 192
# Scores: (min: 12, avg: 172.79, max: 500)
#
# Run: 564, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 176.08, max: 500)
#
# Run: 565, exploration: 0.01, score: 263
# Scores: (min: 12, avg: 175.52, max: 500)
#
# Run: 566, exploration: 0.01, score: 93
# Scores: (min: 12, avg: 173.04, max: 500)
#
# Run: 567, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 175.18, max: 500)
#
# Run: 568, exploration: 0.01, score: 173
# Scores: (min: 12, avg: 175.45, max: 500)
#
# Run: 569, exploration: 0.01, score: 122
# Scores: (min: 12, avg: 173.84, max: 500)
#
# Run: 570, exploration: 0.01, score: 290
# Scores: (min: 12, avg: 173.99, max: 500)
#
# Run: 571, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 177.05, max: 500)
#
# Run: 572, exploration: 0.01, score: 113
# Scores: (min: 12, avg: 177.06, max: 500)
#
# Run: 573, exploration: 0.01, score: 146
# Scores: (min: 12, avg: 174.22, max: 500)
#
# Run: 574, exploration: 0.01, score: 110
# Scores: (min: 12, avg: 173.71, max: 500)
#
# Run: 575, exploration: 0.01, score: 94
# Scores: (min: 12, avg: 173.28, max: 500)
#
# Run: 576, exploration: 0.01, score: 222
# Scores: (min: 12, avg: 174.4, max: 500)
#
# Run: 577, exploration: 0.01, score: 139
# Scores: (min: 12, avg: 174.56, max: 500)
#
# Run: 578, exploration: 0.01, score: 190
# Scores: (min: 12, avg: 175.32, max: 500)
#
# Run: 579, exploration: 0.01, score: 145
# Scores: (min: 12, avg: 175, max: 500)
#
# Run: 580, exploration: 0.01, score: 195
# Scores: (min: 12, avg: 175.85, max: 500)
#
# Run: 581, exploration: 0.01, score: 184
# Scores: (min: 12, avg: 175.79, max: 500)
#
# Run: 582, exploration: 0.01, score: 117
# Scores: (min: 12, avg: 174.04, max: 500)
#
# Run: 583, exploration: 0.01, score: 273
# Scores: (min: 12, avg: 175.52, max: 500)
#
# Run: 584, exploration: 0.01, score: 140
# Scores: (min: 12, avg: 174.39, max: 500)
#
# Run: 585, exploration: 0.01, score: 109
# Scores: (min: 12, avg: 173.91, max: 500)
#
# Run: 586, exploration: 0.01, score: 266
# Scores: (min: 12, avg: 175.46, max: 500)
#
# Run: 587, exploration: 0.01, score: 138
# Scores: (min: 12, avg: 174.27, max: 500)
#
# Run: 588, exploration: 0.01, score: 248
# Scores: (min: 12, avg: 174.31, max: 500)
#
# Run: 589, exploration: 0.01, score: 159
# Scores: (min: 12, avg: 174.93, max: 500)
#
# Run: 590, exploration: 0.01, score: 123
# Scores: (min: 12, avg: 175.87, max: 500)
#
# Run: 591, exploration: 0.01, score: 280
# Scores: (min: 12, avg: 178.31, max: 500)
#
# Run: 592, exploration: 0.01, score: 309
# Scores: (min: 12, avg: 179.8, max: 500)
#
# Run: 593, exploration: 0.01, score: 286
# Scores: (min: 12, avg: 180.06, max: 500)
#
# Run: 594, exploration: 0.01, score: 27
# Scores: (min: 12, avg: 178.46, max: 500)
#
# Run: 595, exploration: 0.01, score: 301
# Scores: (min: 12, avg: 179.82, max: 500)
#
# Run: 596, exploration: 0.01, score: 180
# Scores: (min: 12, avg: 180.48, max: 500)
#
# Run: 597, exploration: 0.01, score: 165
# Scores: (min: 12, avg: 180.2, max: 500)
#
# Run: 598, exploration: 0.01, score: 90
# Scores: (min: 12, avg: 179.78, max: 500)
#
# Run: 599, exploration: 0.01, score: 372
# Scores: (min: 12, avg: 183.32, max: 500)
#
# Run: 600, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 188.16, max: 500)
#
# Run: 601, exploration: 0.01, score: 137
# Scores: (min: 12, avg: 189.37, max: 500)
#
# Run: 602, exploration: 0.01, score: 107
# Scores: (min: 12, avg: 190.31, max: 500)
#
# Run: 603, exploration: 0.01, score: 377
# Scores: (min: 12, avg: 191.51, max: 500)
#
# Run: 604, exploration: 0.01, score: 176
# Scores: (min: 12, avg: 190.74, max: 500)
#
# Run: 605, exploration: 0.01, score: 70
# Scores: (min: 12, avg: 190.46, max: 500)
#
# Run: 606, exploration: 0.01, score: 76
# Scores: (min: 12, avg: 189.89, max: 500)
#
# Run: 607, exploration: 0.01, score: 203
# Scores: (min: 12, avg: 190.55, max: 500)
#
# Run: 608, exploration: 0.01, score: 148
# Scores: (min: 12, avg: 191.05, max: 500)
#
# Run: 609, exploration: 0.01, score: 148
# Scores: (min: 12, avg: 191.74, max: 500)
#
# Run: 610, exploration: 0.01, score: 170
# Scores: (min: 12, avg: 190.93, max: 500)
#
# Run: 611, exploration: 0.01, score: 14
# Scores: (min: 12, avg: 190.66, max: 500)
#
# Run: 612, exploration: 0.01, score: 295
# Scores: (min: 12, avg: 192.48, max: 500)
#
# Run: 613, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 196.53, max: 500)
#
# Solved in 513 runs, 613 total runs.

# %% [markdown]
# - **Explain how reinforcement learning concepts apply to the cartpole problem.**
#   - What is the goal of the agent in this case?
#     - The goal of the agent is to move a cart either left or right in a manner that keeps a pole with a weight at the top balanced on said cart. It can be thought of as balancing a pendulum on your hand, but the range of motion is only on an X-axis rather than X and Z axes.
#   - What are the various state values?
#     - The state values are found in the _observation\_space_ parameter. They correspond to the cart's position, the cart's velocity, the pole's angle, and the velocity of the pole at its tip (Surma, 2018).
#   - What are the possible actions that can be performed?
#     - The agent can only take make one of two actions. Move the cart left (0) or move the cart right (1) (Surma, 2018).
#   - What reinforcement algorithm is used for this problem?
#     - The code we are given uses the Deep Q-Learning algorithm.
# - **Analyze how experience replay is applied to the cartpole problem.**
#   - How does experience replay work in this algorithm? -
#     - Experience replay works in this algorithm by attempting to adjust the weights of the neural network in a way where it can predict the Q-values of the different state/action pairs which would in turn allow it to take the most optimal actions at a given state to maximize the total rewards received. It does this by keeping track of its experiences during each time step. An experience of a given time step is made up of the state at said time step, the action taken at said time step, the reward given to the agent for taking the action, and the resulting state of the action taken. So, after each time step/action, the program stores its experience. It then uses a batch of experiences as the training data for the neural network with the goal of training the neural network well enough that it can produce accurate Q-value estimations like previously stated (Deeplizard, 2018).
#   - What is the effect of introducing a discount factor for calculating the future rewards?
#     - The purpose of Q-learning is for the AI to make decisions based on maximizing the rewards earned. This can take multiple steps to accomplish. During this, there can be some uncertainty about actually obtaining later rewards. This makes a later reward of the same value as a current reward worth less at the current step. For example, say that you had the reward of possibly getting a piece of cake in the next 5 minutes versus the possibility of getting a piece of cake the same size, flavor, etc. in 5 days. The reward is the same, but the future is uncertain. Therefore, the possibility of getting the cake in 5 minutes is inherently more valuable than the possibility of getting the cake in 5 days.
# - **Analyze how neural networks are used in deep Q-learning.**
#   - Explain the neural network architecture that is used in the cartpole problem.
#     - The neural network for this problem is made up of three layers. An input layer, a hidden layer, and an output layer. The input layer has an input shape of 4. This corresponds to the observation space, which are the different state factors such as cart position, pole angle, cart velocity, and pole velocity. This layer outputs to the hidden layer, which has 24 nodes. The hidden layer uses the rectified linear unit activation function and passes the value to the output layer. This layer "converges" into two outputs. The two outputs correspond to the two available actions for the AI, move the cart left or move the cart right.
#   - How does the neural network make the Q-learning algorithm more efficient?
#     - For the cart pole problem, there aren't many state-action pairs, so it isn't such a large task for a computer to manually calculate the Q-values after each step, but some tasks have many state-action pairs. Obviously, the more states and actions there are, the more state-action pairs there will be, then the more compute intensive it will be to update each state-action pair's Q-value after each step. The neural network makes this more efficient by using past experiences to estimate the Q-values for the available actions at the current state rather than calculating them manually.
#   - What difference do you see in the algorithm performance when you increase or decrease the learning rate?
#     - I changed the learning rate of the algorithm from 0.001 to 0.1 and it was never able to "win" the cartpole game. This is caused by the algorithm "over correcting" or adjusting the model's weights too much after each pass. An easier way to understand this is if you were shooting an arrow at a target and say you miss to the right by 1 foot. If you're learning rate is too high, you might try to hit the bullseye by adjusting your aim to the left, but you aim too far to the left and miss your second shot by 0.9 feet to the left. You try to correct your next shot by aiming to the right, but you over correct again and miss to the right by 1.1 feet. You keep over correcting, shot after shot, and maybe get close to the center a few times, but the over corrections throw your aim way off again. If you have a learning rate that is too small, you under correct. Looking at that first shot that is off to the right by 1 foot, you under adjust your aim. Your next shot is still off to the right, but only 0.98 feet this time. The next shot is closer, but still off to the right by 0.96 feet. It will take you many shots to finally hit the bullseye. To circle back to the question, the basic answer is that a learning rate that is too large will cause the algorithm to repeatedly overshoot the optimal solution while a learning rate that is too small will require way too many epochs to eventually reach the optimal solution (Brownlee, 2019).
#
# ##### References
# Brownlee, J. (2019, January 25). _Understand the Impact of Learning Rate on Neural Network Performance_. Retrieved from Machine Learning Mastery: https://machinelearningmastery.com/understand-the-dynamics-of-learning-rate-on-deep-learning-neural-networks/
#
# Deeplizard. (2018, November 2). _Reinforcement Learning - Developing Intelligent Agents_. Retrieved from Deeplizard: https://deeplizard.com/learn/video/Bcuj2fTH4\_4
#
# Surma, G. (2018, September 26). _Cartpole - Introduction to Reinforcement Learning (DQN - Deep Q-Learning)_. Retrieved from Medium: https://gsurma.medium.com/cartpole-introduction-to-reinforcement-learning-ed0eb5b58288
